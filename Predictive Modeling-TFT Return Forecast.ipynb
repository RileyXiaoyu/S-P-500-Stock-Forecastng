# %%
# !pip install pytorch_lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.0.0-py3-none-any.whl (715 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.6/715.6 KB 15.2 MB/s eta 0:00:00
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 24.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning) (1.13.1+cu116)
# Collecting lightning-utilities>=0.7.0
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning) (4.65.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning) (2023.3.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning) (4.5.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning) (1.22.4)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning) (23.0)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (2.25.1)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 10.0 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (22.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 3.9 MB/s eta 0:00:00
# Collecting charset-normalizer<4.0,>=2.0
#   Downloading charset_normalizer-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2.10)
# Installing collected packages: multidict, lightning-utilities, frozenlist, charset-normalizer, async-timeout, yarl, torchmetrics, aiosignal, aiohttp, pytorch_lightning
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 charset-normalizer-3.1.0 frozenlist-1.3.3 lightning-utilities-0.8.0 multidict-6.0.4 pytorch_lightning-2.0.0 torchmetrics-0.11.4 yarl-1.8.2

# %%
# !pip install pytorch_forecasting
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch_forecasting
#   Downloading pytorch_forecasting-0.10.3-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.4/141.4 KB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.9/dist-packages (from pytorch_forecasting) (0.13.5)
# Requirement already satisfied: scipy<2.0,>=1.8 in /usr/local/lib/python3.9/dist-packages (from pytorch_forecasting) (1.10.1)
# Collecting scikit-learn<1.2,>=0.24
#   Downloading scikit_learn-1.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 47.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from pytorch_forecasting) (3.7.1)
# Collecting pytorch-lightning<2.0.0,>=1.2.4
#   Downloading pytorch_lightning-1.9.4-py3-none-any.whl (827 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 KB 5.6 MB/s eta 0:00:00
# Collecting optuna<3.0.0,>=2.3.0
#   Downloading optuna-2.10.1-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.2/308.2 KB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_forecasting) (1.4.4)
# Requirement already satisfied: torch<2.0,>=1.7 in /usr/local/lib/python3.9/dist-packages (from pytorch_forecasting) (1.13.1+cu116)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (1.22.4)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting cliff
#   Downloading cliff-4.2.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 KB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (23.0)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (4.65.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (1.4.46)
# Collecting alembic
#   Downloading alembic-1.10.2-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<2.0.0,>=1.3.0->pytorch_forecasting) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas<2.0.0,>=1.3.0->pytorch_forecasting) (2.8.2)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (0.8.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (0.11.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (4.5.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.9/dist-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2023.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<1.2,>=0.24->pytorch_forecasting) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn<1.2,>=0.24->pytorch_forecasting) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pytorch_forecasting) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pytorch_forecasting) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pytorch_forecasting) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pytorch_forecasting) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pytorch_forecasting) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pytorch_forecasting) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->pytorch_forecasting) (1.4.4)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels->pytorch_forecasting) (0.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2.25.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.9/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (3.8.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->pytorch_forecasting) (3.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from patsy>=0.5.2->statsmodels->pytorch_forecasting) (1.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.9/dist-packages (from sqlalchemy>=1.1.0->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (2.0.2)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (6.0.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.9/dist-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (3.6.0)
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.2/147.2 KB 17.5 MB/s eta 0:00:00
# Collecting stevedore>=2.0.1
#   Downloading stevedore-5.0.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (3.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (4.0.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.9/dist-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (0.2.6)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.11.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 KB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from Mako->alembic->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.26.15)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2.10)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11135 sha256=b173a6d1d8823daf2d34780bfa14857783b427a8ce5df5247fca61413e68b71c
#   Stored in directory: /root/.cache/pip/wheels/0c/09/9e/49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, Mako, colorlog, cmd2, cmaes, autopage, stevedore, scikit-learn, alembic, cliff, pytorch-lightning, optuna, pytorch_forecasting
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.0.0
#     Uninstalling pytorch-lightning-2.0.0:
#       Successfully uninstalled pytorch-lightning-2.0.0
# Successfully installed Mako-1.2.4 alembic-1.10.2 autopage-0.5.1 cliff-4.2.0 cmaes-0.9.1 cmd2-2.4.3 colorlog-6.7.0 optuna-2.10.1 pbr-5.11.1 pyperclip-1.8.2 pytorch-lightning-1.9.4 pytorch_forecasting-0.10.3 scikit-learn-1.1.3 stevedore-5.0.0

# %%
import copy
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping, LearningRateMonitor
from pytorch_lightning.loggers import TensorBoardLogger
import torch

from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

# %%
df = pd.read_csv("final_data2.csv")
df = df.sort_values('date')
df.head()
# Out:
#        gvkey  month  year       date  \
# 0       1013     12  1997  1998/1/31
# 86340   9351     12  1997  1998/1/31
# 86468   9357     12  1997  1998/1/31
# 86472   9359     12  1997  1998/1/31
# 5290    1478     12  1997  1998/1/31
#
#                                                ggroup   gsubind  \
# 0                     Technology Hardware & Equipment  45201020
# 86340                                       Insurance  40301040
# 86468              Commercial & Professional Services  20201050
# 86472                        Food & Staples Retailing  30101030
# 5290   Pharmaceuticals, Biotechnology & Life Sciences  35202010
#
#                              conm       dpr  PEG_trailing        bm  ...  \
# 0      ADC TELECOMMUNICATIONS INC  0.000000     -0.072822 -0.709247  ...
# 86340                 SAFECO CORP  0.000000     -0.098360  1.214410  ...
# 86468       SAFETY-KLEEN CORP-OLD -0.057466      0.286446  0.017754  ...
# 86472                 SAFEWAY INC  0.000000      0.000000  0.000000  ...
# 5290                        WYETH -0.013251      0.000000  0.000000  ...
#
#        Currency in Circulation  \
# 0                    -0.001059
# 86340                -0.001059
# 86468                -0.001059
# 86472                -0.001059
# 5290                 -0.001059
#
#        10-Year Treasury Constant Maturity Minus Federal Funds Rate  \
# 0                                                   -2.0
# 86340                                                0.0
# 86468                                               -2.0
# 86472                                               -2.0
# 5290                                                 0.0
#
#        Rent Inflation Rate  US GDP Growth Rate    trt1m  risk1y      trt1y  \
# 0                  0.24939            0.011473 -54.3401     NaN -16.766539
# 86340              0.24939            0.011473   3.0913     NaN  -9.371368
# 86468              0.24939            0.011473  -5.2374     NaN        NaN
# 86472              0.24939            0.011473   5.0387     NaN  92.687423
# 5290               0.24939            0.011473  24.7542     NaN  49.987927
#
#        risk2y      trt6m    risk1m
# 0         NaN -12.500010  0.289374
# 86340     NaN  -5.726436  0.001323
# 86468     NaN        NaN  0.002200
# 86472     NaN  28.656101  0.003120
# 5290      NaN  36.519336  0.064013
#
# [5 rows x 159 columns]

# %%
df.reset_index(inplace=True)
df.drop(columns=['index', 'risk1y', 'trt1y', 'risk2y', 'trt6m', 'risk1m'],inplace=True)

# %%
df["trt1m"] = df["trt1m"].clip(upper = 50,lower =-50)

# %%
df["trt1m"] = df.groupby('date')["trt1m"].transform(lambda x: (x - x.mean()) / x.std())

# %%
df["time_idx"] = df["year"] * 12 + df["month"]
df["time_idx"] -= df["time_idx"].min()
df['time_idx'] = df['time_idx'].astype(int)
#data = data.set_index("date")
#data = data.resample("M").last()  # resample to monthly frequency
#data = data.reset_index()
df.drop(columns=['month','year','ggroup','gsubind','conm', 'int_totdebt', 'cash_conversion', 'prccm', 'prchm', 'prclm', 'Market_Cap', 'Market_Cap_missing'],inplace=True)
df = df.dropna(axis=0)

#train_data = data[data['date'] <= '2018-01-01']
#test_data = data[data['date'] >= '2018-01-01']

data_prior2014=df[df['date']<='2014-01-01']
val_data_2 =df[(df['date']>='2014-01-01')&(df['date']<='2018-01-01')]
test_data =df[df['date']>='2016-01-01']

# %%
list_gvkey=data_prior2014['gvkey'].unique()
df_gvkey=pd.DataFrame({'gvkey':list_gvkey})
train_set=df_gvkey.sample(n=int(len(df_gvkey)*0.6))
valid_set=df_gvkey[(df_gvkey['gvkey'].isin(list(train_set['gvkey']))==False)]

train_data =data_prior2014[data_prior2014['gvkey'].isin(train_set['gvkey'])]
val_data_1 =data_prior2014[data_prior2014['gvkey'].isin(valid_set['gvkey'])]

# %%
train_data.sort_values(by=['gvkey','date'],inplace=True)
train_data.reset_index(inplace=True)
train_data.drop(columns='index',inplace=True)

# %%
val_data_1.sort_values(by=['gvkey','date'],inplace=True)
val_data_1.reset_index(inplace=True)
val_data_1.drop(columns='index',inplace=True)

# %%
val_data_2.sort_values(by=['gvkey','date'],inplace=True)
val_data_2.reset_index(inplace=True)
val_data_2.drop(columns='index',inplace=True)

# %%
test_data.sort_values(by=['gvkey','date'],inplace=True)
test_data.reset_index(inplace=True)
test_data.drop(columns='index',inplace=True)

# %%
list_to_remove = ['gvkey', 'date','time_idx']
col_list = set(list(df.columns)) - set(list_to_remove)
col_list = list(col_list)

# %%
val_data_1
# Out:
#         gvkey        date  dpr  PEG_trailing   bm  CAPEI  divyield       evm  \
# 0        1045   1998/1/31  0.0     -0.375444  0.0    0.0       0.0 -0.394211
# 1        1045  1998/10/31  0.0     -0.312043  0.0    0.0       0.0 -0.091918
# 2        1045  1998/11/30  0.0     -0.310484  0.0    0.0       0.0 -0.093385
# 3        1045  1998/12/31  0.0     -0.308304  0.0    0.0       0.0  0.000226
# 4        1045   1998/2/28  0.0     -0.373109  0.0    0.0       0.0 -0.392817
# ...       ...         ...  ...           ...  ...    ...       ...       ...
# 55602  260774   2013/5/31  0.0     -0.337483  0.0    0.0       0.0  0.033183
# 55603  260774   2013/6/30  0.0     -0.321627  0.0    0.0       0.0 -0.005037
# 55604  260774   2013/7/31  0.0     -0.316462  0.0    0.0       0.0 -0.010591
# 55605  260774   2013/8/31  0.0     -0.329503  0.0    0.0       0.0 -0.030592
# 55606  260774   2013/9/30  0.0     -0.280715  0.0    0.0       0.0  0.056371
#
#             pcf    pe_exi  ...  US Population  Bank Prime Loan Rate        M2  \
# 0      0.000000 -0.220625  ...       0.000849                   0.0 -0.008832
# 1      0.000000 -0.099717  ...       0.001015                   0.0 -0.004558
# 2      0.000000 -0.070608  ...       0.000945                   0.0  0.003484
# 3      0.000000 -0.083624  ...       0.000923                   0.0 -0.000863
# 4      0.000000 -0.203136  ...       0.000768                   0.0 -0.001078
# ...         ...       ...  ...            ...                   ...       ...
# 55602  0.816225  0.154602  ...       0.000613                   0.0 -0.003008
# 55603  0.167721  0.109262  ...       0.000647                   0.0 -0.010615
# 55604  0.170029  0.110244  ...       0.000700                   0.0 -0.001229
# 55605  0.134091  0.088729  ...       0.000760                   0.0 -0.002834
# 55606  0.029182  0.093568  ...       0.000750                   0.0  0.006432
#
#        Bank Credit, All Commercial Banks  Currency in Circulation  \
# 0                              -0.001099                 0.000000
# 1                               0.005219                 0.000000
# 2                               0.001787                 0.000000
# 3                               0.002935                 0.000000
# 4                               0.002307                 0.000000
# ...                                  ...                      ...
# 55602                          -0.000745                 0.005605
# 55603                          -0.001703                 0.003938
# 55604                           0.000395                 0.005790
# 55605                          -0.000338                 0.001853
# 55606                          -0.001314                 0.006280
#
#        10-Year Treasury Constant Maturity Minus Federal Funds Rate  \
# 0                                              -2.000000
# 1                                               0.014286
# 2                                              11.333333
# 3                                              -4.866667
# 4                                               0.250000
# ...                                                  ...
# 55602                                           0.009756
# 55603                                           0.020833
# 55604                                          -0.011811
# 55605                                           0.014981
# 55606                                           0.007812
#
#        Rent Inflation Rate  US GDP Growth Rate     trt1m  time_idx
# 0                 0.249390            0.011473 -0.104834         0
# 1                -0.002884            0.018955  0.876648         9
# 2                -0.002875            0.018955 -0.604165        10
# 3                -0.202294            0.018955 -1.184654        11
# 4                -0.002361            0.011473 -0.962368         1
# ...                    ...                 ...       ...       ...
# 55602             0.518578            0.004240 -1.023224       184
# 55603            -0.185686            0.004240  0.295379       185
# 55604            -0.314681            0.012666 -1.037908       186
# 55605             1.304266            0.012666 -0.523651       187
# 55606            -0.507466            0.012666  0.170928       188
#
# [55607 rows x 143 columns]

# %%
# Set hyperparameters
n_epochs = 50 # maybe reduce it 
batch_size = 32
n_time_steps = 24 # make it bigger between 24 to 48 
n_features = 147 # select few important features 
hidden_layer_size = 128
n_predictions = 6 # bettween 6 to 12 


# Define time series dataset
training_data = TimeSeriesDataSet(
    train_data,
    time_idx="time_idx",
    target="trt1m",
    group_ids=["gvkey"],
    time_varying_unknown_reals= col_list, # filter it 
    max_encoder_length=n_time_steps,
    max_prediction_length=n_predictions,
    allow_missing_timesteps=True,
    time_varying_known_reals=["time_idx"]
)

# %%
testing_data = TimeSeriesDataSet(
    test_data,
    time_idx="time_idx",
    target="trt1m",
    group_ids=["gvkey"],
    time_varying_unknown_reals= col_list,
    max_encoder_length=n_time_steps,
    max_prediction_length=n_predictions,
    allow_missing_timesteps=True,
    time_varying_known_reals=["time_idx"]
)

testing_data2 = TimeSeriesDataSet(
    df,
    time_idx="time_idx",
    target="trt1m",
    group_ids=["gvkey"],
    time_varying_unknown_reals= col_list,
    max_encoder_length=n_time_steps,
    max_prediction_length=n_predictions,
    allow_missing_timesteps=True,
    time_varying_known_reals=["time_idx"]
)

# %%
validation_data_1 = TimeSeriesDataSet(
    val_data_1,
    time_idx="time_idx",
    target="trt1m",
    group_ids=["gvkey"],
    time_varying_unknown_reals= col_list,
    max_encoder_length=n_time_steps,
    max_prediction_length=n_predictions,
    allow_missing_timesteps=True,
    time_varying_known_reals=["time_idx"]
)

validation_data_2 = TimeSeriesDataSet(
    val_data_2,
    time_idx="time_idx",
    target="trt1m",
    group_ids=["gvkey"],
    time_varying_unknown_reals= col_list,
    max_encoder_length=n_time_steps,
    max_prediction_length=n_predictions,
    allow_missing_timesteps=True,
    time_varying_known_reals=["time_idx"]
)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
# create dataloaders for model
batch_size = 128  # set this between 32 to 128

train_dataloader = training_data.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
val_dataloader_1 = validation_data_1.to_dataloader(train=False, batch_size=batch_size, num_workers=0)
val_dataloader_2 = validation_data_2.to_dataloader(train=False, batch_size=batch_size, num_workers=0)
testing_dataloader = testing_data.to_dataloader(train=False, batch_size=batch_size * 10, num_workers=0)
testing_dataloader2 = testing_data2.to_dataloader(train=False, batch_size=batch_size * 10, num_workers=0)

# %%
# configure network and trainer
pl.seed_everything(42)
trainer = pl.Trainer(
    gpus=0,
    # clipping gradients is a hyperparameter and important to prevent divergance
    # of the gradient for recurrent neural networks
    gradient_clip_val=0.1,
)


tft = TemporalFusionTransformer.from_dataset(
    training_data,
    # not meaningful for finding the learning rate but otherwise very important
    learning_rate=0.03,
    hidden_size=16,  # most important hyperparameter apart from learning rate, try lower value 
    # number of attention heads. Set to up to 4 for large datasets
    attention_head_size=1,
    dropout=0.1,  # between 0.1 and 0.3 are good values
    hidden_continuous_size=8,  # set to <= hidden_size
    output_size=7,  # 7 quantiles by default
    loss=QuantileLoss(),
    # reduce learning rate if no improvement in validation loss after x epochs
    reduce_on_plateau_patience=4,
)
print(f"Number of parameters in network: {tft.size()/1e3:.1f}k")
# Out:
# Global seed set to 42
# d:\Python\lib\site-packages\pytorch_lightning\trainer\connectors\accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=0)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=0)` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Number of parameters in network: 113.3k

# %%
# configure network and trainer
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=10, verbose=False, mode="min")
lr_logger = LearningRateMonitor()  # log the learning rate
logger = TensorBoardLogger("lightning_logs")  # logging results to a tensorboard

trainer = pl.Trainer(
    max_epochs=30,
    auto_select_gpus=True,
    accelerator='gpu',
    enable_model_summary=True,
    gradient_clip_val=0.1,
    limit_train_batches=30,  # coment in for training, running valiation every 30 batches
    # fast_dev_run=True,  # comment in to check that networkor dataset has no serious bugs
    callbacks=[lr_logger, early_stop_callback],
    logger=logger,
)

tft = TemporalFusionTransformer.from_dataset(
    training_data,
    learning_rate=0.03,
    hidden_size=16,
    attention_head_size=1,
    dropout=0.1,
    hidden_continuous_size=8,
    output_size=7,  # 7 quantiles by default
    loss=QuantileLoss(),
    log_interval=10,  # uncomment for learning rate finder and otherwise, e.g. to 10 for logging every 10 batches
    reduce_on_plateau_patience=4,
)
print(f"Number of parameters in network: {tft.size()/1e3:.1f}k")
# Out:
# d:\Python\lib\site-packages\pytorch_lightning\trainer\connectors\accelerator_connector.py:578: LightningDeprecationWarning: The Trainer argument `auto_select_gpus` has been deprecated in v1.9.0 and will be removed in v2.0.0. Please use the function `pytorch_lightning.accelerators.find_usable_cuda_devices` instead.
#   rank_zero_deprecation(
# Auto select gpus: [0]
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Number of parameters in network: 113.3k

# %%
trainer.fit(
    tft,
    train_dataloaders=train_dataloader,
    val_dataloaders= val_dataloader_1,
)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 0
# 3  | prescalers                         | ModuleDict                      | 2.3 K
# 4  | static_variable_selection          | VariableSelectionNetwork        | 0
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 98.5 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 528
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K
# 11 | lstm_encoder                       | LSTM                            | 2.2 K
# 12 | lstm_decoder                       | LSTM                            | 2.2 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576
# 20 | output_layer                       | Linear                          | 119
# ----------------------------------------------------------------------------------------
# 113 K     Trainable params
# 0         Non-trainable params
# 113 K     Total params
# 0.453     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %%
from sklearn.metrics import mean_squared_error
import pandas as pd
 
def compute_averages(df):
    num_rows, num_cols = df.shape
    output = []
 
    for i in range(num_rows + num_cols - 1):
        total = 0
        count = 0
 
        for j in range(max(0, i - num_cols + 1), min(i + 1, num_rows)):
            total += df.iloc[j, i - j]
            count += 1
 
        output.append(total / count)
 
    return output

def get_predict(model, dataloader, timeseires_dataset, dataset):
    predictions, index1 = model.predict(dataloader, return_index=True)
    predictions_array = predictions.numpy()
    df_predictions = pd.DataFrame(predictions_array, columns=['predictions t+{}'.format(i) for i in range(predictions_array.shape[1])])
    mean_results = compute_averages(df_predictions)

    predictions_array2 = model.output_transformer.inverse_transform(predictions).numpy()
    df_predictions2 = pd.DataFrame(predictions_array2, columns=['predictions t+{}'.format(i) for i in range(predictions_array2.shape[1])])
    mean_results2 = compute_averages(df_predictions2)

    index = timeseires_dataset.decoded_index.copy()
    index['prediction'] = mean_results[:-5]
    index['prediction_decode'] = mean_results2[:-5]

    new_data = pd.merge(dataset, index, left_on=['gvkey', 'time_idx'], right_on=['gvkey', 'time_idx_first_prediction'], how='left')
    new_data = new_data.drop(columns=['time_idx_first_prediction', 'time_idx_first', 'time_idx_last'])
    # select the last 5 rows of the "predict" column using .iloc
    new_data.iloc[-5:, -2] = mean_results[-5:]
    new_data.iloc[-5:, -1] = mean_results2[-5:]

    final_data = new_data[new_data['date']>='2018-01-01']
    final_data = final_data.dropna()
    final_data.sort_values(by=['gvkey','date'],inplace=True)
    final_data.reset_index(inplace=True)
    final_data.drop(columns=['index'],inplace=True)

    per_period_median_prediction = final_data.groupby('date')['prediction_decode'].apply(lambda x: np.percentile(x, 50)).reset_index()
    per_period_median_prediction = per_period_median_prediction.rename(columns={'prediction_decode':"predict_median"})
    per_period_median_actual = final_data.groupby('date')['trt1m'].apply(lambda x: np.percentile(x, 50)).reset_index()
    per_period_median_actual = per_period_median_actual.rename(columns={'trt1m':"actual_median"})
    data_roc = final_data.merge(per_period_median_prediction, on='date')
    data_roc = data_roc.merge(per_period_median_actual, on='date')
    data_roc['prediction_decode_fix'] = data_roc['prediction_decode'] - data_roc['predict_median'] + data_roc['actual_median']
    data_roc = data_roc.drop(columns=['predict_median', 'actual_median'])

    print("mse", mean_squared_error(data_roc['prediction'],data_roc['trt1m']))
    return data_roc

# %%
final_data = get_predict(tft, testing_dataloader2, testing_data2, df)
final_data
# Out:
# mse 1.0014179041490041
#         gvkey       date       dpr  PEG_trailing        bm     CAPEI  \
# 0        1045  2018/1/31  0.000000      0.000000  0.000000  0.000000
# 1        1075  2018/1/31  0.000000      0.000000  0.927742 -0.002988
# 2        1078  2018/1/31  0.006169     -0.186223  0.000000  0.156408
# 3        1161  2018/1/31  0.000000     -0.376500 -0.822953 -0.175380
# 4        1177  2018/1/31 -0.112942      5.055414 -0.294288  0.024273
# ...       ...        ...       ...           ...       ...       ...
# 25213   10035  2022/1/31 -0.069822      0.583847  0.778903 -0.020292
# 25214   17874  2022/1/31  0.000000     -0.514286  0.135492  0.082959
# 25215   28070  2022/1/31  0.000000     -0.499837  0.403580 -0.006272
# 25216   32106  2022/1/31  0.352906     -0.451673  0.490957 -0.096864
# 25217  170617  2022/1/31  0.000000     -0.252138 -0.565508  0.052722
#
#        divyield       evm       pcf    pe_exi  ...  \
# 0     -0.638283  0.000000  0.000000  0.000000  ...
# 1      0.565653 -0.067657 -0.252905  0.000000  ...
# 2      0.000000  0.000000  0.153418  0.355412  ...
# 3      0.000000  0.276494 -3.725378  0.000000  ...
# 4     -0.473473 -0.065899  1.146568  0.159627  ...
# ...         ...       ...       ...       ...  ...
# 25213  0.328110 -0.175117 -0.619378 -0.235337  ...
# 25214  0.000000 -0.098105 -0.227753  0.264785  ...
# 25215 -0.698229 -0.219666 -0.345254 -0.305476  ...
# 25216  0.726831 -0.109354 -0.201026  1.032818  ...
# 25217  0.000000  0.033785 -0.105816 -0.061376  ...
#
#        Bank Credit, All Commercial Banks  Currency in Circulation  \
# 0                               0.000149                 0.004236
# 1                               0.000149                 0.004236
# 2                               0.000149                 0.004236
# 3                               0.000149                 0.004236
# 4                               0.000149                 0.004236
# ...                                  ...                      ...
# 25213                           0.000549                 0.004371
# 25214                           0.000549                 0.004371
# 25215                           0.000549                 0.004371
# 25216                           0.000549                 0.004371
# 25217                           0.000549                 0.004371
#
#        10-Year Treasury Constant Maturity Minus Federal Funds Rate  \
# 0                                               0.053435
# 1                                               0.000000
# 2                                               0.053435
# 3                                               0.000000
# 4                                               0.053435
# ...                                                  ...
# 25213                                           0.005882
# 25214                                           0.005882
# 25215                                           0.005882
# 25216                                           0.005882
# 25217                                           0.005882
#
#        Rent Inflation Rate  US GDP Growth Rate     trt1m  time_idx  \
# 0                -0.087386            0.013106 -0.058787       240
# 1                -0.087386            0.013106 -1.263860       240
# 2                -0.087386            0.013106  0.561785       240
# 3                 0.000000            0.000000  3.566394       240
# 4                -0.087386            0.013106 -0.128128       240
# ...                    ...                 ...       ...       ...
# 25213             0.434208            0.016073  0.580843       288
# 25214             0.434208            0.016073 -0.279148       288
# 25215             0.434208            0.016073 -0.710514       288
# 25216             0.434208            0.016073  1.862083       288
# 25217             0.434208            0.016073 -0.292645       288
#
#        prediction  prediction_decode  prediction_decode_fix
# 0       -0.070321           0.030012              -0.009608
# 1        0.045887           0.105549               0.065930
# 2       -0.018934           0.063415               0.023795
# 3        0.867255           0.639455               0.599835
# 4        0.024859           0.091881               0.052261
# ...           ...                ...                    ...
# 25213    0.137557           0.165137              -0.280622
# 25214    0.167534           0.184622              -0.261136
# 25215    0.139824           0.166610              -0.279148
# 25216    0.144742           0.169807              -0.275951
# 25217    0.127582           0.158653              -0.287105
#
# [25218 rows x 146 columns]

# %%
final_data.to_csv("tft_results2.csv", index=False)

# %%
final_data = pd.read_csv("tft_results2.csv")

# %%
sample_stock2 = final_data[final_data['gvkey']==4517]
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18,5))
ax = sns.lineplot(data=pd.DataFrame({'Predicted':sample_stock2['prediction_decode_fix'],'Actual':sample_stock2['trt1m']}))
#ax.set_xticks(range(0, len(sample_stock2), 5))
ax.set_xticklabels(sample_stock2.date[::5], rotation=45, ha='right')
plt.show()

sample_loss = mean_squared_error(sample_stock2['prediction_decode_fix'], sample_stock2['trt1m'])
sample_loss
# Out:
# 0.44515962703587547

# %%
sample_stock2 = final_data[final_data['gvkey']==187697]
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18,5))
ax = sns.lineplot(data=pd.DataFrame({'Predicted':sample_stock2['prediction_decode_fix'],'Actual':sample_stock2['trt1m']}))
#ax.set_xticks(range(0, len(sample_stock2), 5))
ax.set_xticklabels(sample_stock2.date[::5], rotation=45, ha='right')
plt.show()

sample_loss = mean_squared_error(sample_stock2['prediction_decode_fix'], sample_stock2['trt1m'])
sample_loss
# Out:
# 0.5484119891309397

# %%
per_period_median_prediction = final_data.groupby('date')['prediction_decode_fix'].apply(lambda x: np.percentile(x, 50)).reset_index()
per_period_median_prediction = per_period_median_prediction.rename(columns={'prediction_decode_fix':"predict_median"})
per_period_median_actual = final_data.groupby('date')['trt1m'].apply(lambda x: np.percentile(x, 50)).reset_index()
per_period_median_actual = per_period_median_actual.rename(columns={'trt1m':"actual_median"})
data_roc2 = final_data.merge(per_period_median_prediction, on='date')
data_roc2 = data_roc2.merge(per_period_median_actual, on='date')

# %%
data_roc2['binary_target_1'] = data_roc2['trt1m'] >= data_roc2['actual_median']
data_roc2.binary_target_1.mean()
# Out:
# 0.500475850582917

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Calculate false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(data_roc2.binary_target_1, data_roc2.prediction_decode_fix)

# Calculate AUC score
auc_score = roc_auc_score(data_roc2.binary_target_1, data_roc2.prediction_decode_fix)
print(auc_score)
# Out:
# 0.5172371768344425

# %%
trainer.checkpoint_callback.best_model_path
# Out:
# ''

# %%
#best_model_path = trainer.checkpoint_callback.best_model_path
tft = TemporalFusionTransformer.load_from_checkpoint('epoch=20-step=630.ckpt')
tft
# Out:
# TemporalFusionTransformer(
#   	"attention_head_size":               1
#   	"categorical_groups":                {}
#   	"causal_attention":                  True
#   	"dropout":                           0.1
#   	"embedding_labels":                  {}
#   	"embedding_paddings":                []
#   	"embedding_sizes":                   {}
#   	"hidden_continuous_size":            8
#   	"hidden_continuous_sizes":           {}
#   	"hidden_size":                       16
#   	"learning_rate":                     0.03
#   	"log_gradient_flow":                 False
#   	"log_interval":                      10
#   	"log_val_interval":                  10
#   	"logging_metrics":                   ModuleList(
#   	  (0): SMAPE()
#   	  (1): MAE()
#   	  (2): RMSE()
#   	  (3): MAPE()
#   	)
#   	"loss":                              QuantileLoss(quantiles=[0.02, 0.1, 0.25, 0.5, 0.75, 0.9, 0.98])
#   	"lstm_layers":                       1
#   	"max_encoder_length":                24
#   	"monotone_constaints":               {}
#   	"optimizer":                         ranger
#   	"optimizer_params":                  None
#   	"output_size":                       7
#   	"output_transformer":                EncoderNormalizer(
#   		method='standard',
#   		center=True,
#   		max_length=None,
#   		transformation=None,
#   		method_kwargs={}
#   	)
#   	"reduce_on_plateau_min_lr":          1e-05
#   	"reduce_on_plateau_patience":        4
#   	"reduce_on_plateau_reduction":       2.0
#   	"share_single_variable_networks":    False
#   	"static_categoricals":               []
#   	"static_reals":                      []
#   	"time_varying_categoricals_decoder": []
#   	"time_varying_categoricals_encoder": []
#   	"time_varying_reals_decoder":        ['time_idx']
#   	"time_varying_reals_encoder":        ['time_idx', 'intcov', 'PEG_trailing', 'Auto Inventory/Sales Ratio', 'sale_equity', 'ocf_lct', 'ocf_lct_missing', 'pretret_noa', 'Bank Credit, All Commercial Banks', 'Export Price Index (End Use): All Commodities', 'efftax', 'Economic Policy Uncertainty Index for United States', 'capital_ratio', 'cshtrm', 'debt_invcap', 'Federal Government: Current Expenditures', 'debt_capital', 'Average Weeks Unemployed', 'roce', 'lt_debt', 'pay_turn', 'rect_turn', 'lt_ppent', 'pretret_earnat', 'Sticky Consumer Price Index', 'debt_assets', 'rd_sale', 'US dollar Index (Nominal Broad US Dollar Index)', 'int_totdebt_missing', 'Average weekly hours for manufacturing', 'dpr', 'staff_sale', 'fcf_ocf', 'pretret_noa_missing', 'profit_lct_missing', 'rect_act', 'aftret_invcapx', 'Manufacturers new orders for consumer goods and materials', 'ps', '15-Year Fixed Rate Mortgage Average in the United States', '10-Year Treasury Constant Maturity Minus Federal Funds Rate', 'roa', 'US Public debt', 'debt_ebitda', 'US Population', 'Labor Force Participation Rate', 'roe', 'evm', 'Job Openings (Manufacturing)', 'invt_act_missing', 'aftret_equity', 'intcov_ratio_missing', 'CBOE Volatility Index (VIX)', 'cfm', 'US unemployment rate', 'Producer Price Index by Industry (WPI)', 'pcf', 'Manufacturers new orders for non-defense capital goods', 'cash_lt', 'Federal Government Tax Income on Corporate', 'Bank Prime Loan Rate', 'cshoq', 'Manufacturers Inventory/Sales Ratio', 'Commercial and industrial loans outstanding', 'Personal income tax', 'bm', 'int_debt_missing', 'int_debt', 'npm', 'Weekly Economic Index (Lewis-Mertens-Stock)', 'US GDP Growth Rate', 'debt_at', 'totdebt_invcap', 'Security Brokers and Dealers; Margin Accounts at Brokers and Dealers; Asset, Level', 'Energy Inflation (Consumer Price Index for All Urban Consumers: Energy in US City Average)', 'adv_sale', 'M2', 'ptb', 'Loan Performance: Total Loans and Leases: Noncurrent Rate', 'Interest Rates', 'curr_ratio_missing', 'inv_turn', 'accrual', 'divyield', 'Average Weekly Hours of Production and Nonsupervisory Employees, Manufacturing', 'equity_invcap', 'curr_debt_missing', 'Federal government current tax receipts', 'Call Money/Interbank Rate for the United States', 'Industrial Output', 'intcov_ratio', 'short_debt', 'at_turn', 'Equity Market Volatility Tracker: Overall', 'Total unit labor cost', 'pe_op_dil', 'Rent Inflation Rate', 'de_ratio', 'Coincident Economic Activity Index for the United States', 'Velocity of M2 Money Stock', 'pe_inc', 'gpm', 'aftret_eq', 'sale_invcap', 'pe_op_basic', 'Aggregate real person income (less transfer payment)', 'curr_ratio', 'sale_nwc', 'opmad', 'invt_act', 'Consumer Price Index (All Urban Items)', 'cash_debt', 'Imports of Goods and Services', 'dltt_be', 'opmbd', 'trt1m', 'rect_act_missing', 'Retail sales\xa0', 'M1', 'intcov_missing', 'quick_ratio_missing', 'inv_turn_missing', 'CAPEI', 'Food Inflation (Consumer Price Index for All Urban Consumers: Food in US City Average)', 'cash_ratio_missing', 'GProf', 'ptpm', 'pe_exi', 'sale_nwc_missing', 'University of Michigan: Consumer Sentiment', 'cash_conversion_missing', 'curr_debt', '4-Week Moving Average of Continued Claims', 'pretret_earnat_missing', 'profit_lct', 'Building permits for new private housing units ', 'Currency in Circulation', 'quick_ratio', 'Real Estate Loans: Residential Real Estate Loans: Revolving Home Equity Loans, All Commercial Banks', 'Employees on non-agricultural payrolls', 'cash_ratio']
#   	"weight_decay":                      0.0
#   	"x_categoricals":                    []
#   	"x_reals":                           ['time_idx', 'intcov', 'PEG_trailing', 'Auto Inventory/Sales Ratio', 'sale_equity', 'ocf_lct', 'ocf_lct_missing', 'pretret_noa', 'Bank Credit, All Commercial Banks', 'Export Price Index (End Use): All Commodities', 'efftax', 'Economic Policy Uncertainty Index for United States', 'capital_ratio', 'cshtrm', 'debt_invcap', 'Federal Government: Current Expenditures', 'debt_capital', 'Average Weeks Unemployed', 'roce', 'lt_debt', 'pay_turn', 'rect_turn', 'lt_ppent', 'pretret_earnat', 'Sticky Consumer Price Index', 'debt_assets', 'rd_sale', 'US dollar Index (Nominal Broad US Dollar Index)', 'int_totdebt_missing', 'Average weekly hours for manufacturing', 'dpr', 'staff_sale', 'fcf_ocf', 'pretret_noa_missing', 'profit_lct_missing', 'rect_act', 'aftret_invcapx', 'Manufacturers new orders for consumer goods and materials', 'ps', '15-Year Fixed Rate Mortgage Average in the United States', '10-Year Treasury Constant Maturity Minus Federal Funds Rate', 'roa', 'US Public debt', 'debt_ebitda', 'US Population', 'Labor Force Participation Rate', 'roe', 'evm', 'Job Openings (Manufacturing)', 'invt_act_missing', 'aftret_equity', 'intcov_ratio_missing', 'CBOE Volatility Index (VIX)', 'cfm', 'US unemployment rate', 'Producer Price Index by Industry (WPI)', 'pcf', 'Manufacturers new orders for non-defense capital goods', 'cash_lt', 'Federal Government Tax Income on Corporate', 'Bank Prime Loan Rate', 'cshoq', 'Manufacturers Inventory/Sales Ratio', 'Commercial and industrial loans outstanding', 'Personal income tax', 'bm', 'int_debt_missing', 'int_debt', 'npm', 'Weekly Economic Index (Lewis-Mertens-Stock)', 'US GDP Growth Rate', 'debt_at', 'totdebt_invcap', 'Security Brokers and Dealers; Margin Accounts at Brokers and Dealers; Asset, Level', 'Energy Inflation (Consumer Price Index for All Urban Consumers: Energy in US City Average)', 'adv_sale', 'M2', 'ptb', 'Loan Performance: Total Loans and Leases: Noncurrent Rate', 'Interest Rates', 'curr_ratio_missing', 'inv_turn', 'accrual', 'divyield', 'Average Weekly Hours of Production and Nonsupervisory Employees, Manufacturing', 'equity_invcap', 'curr_debt_missing', 'Federal government current tax receipts', 'Call Money/Interbank Rate for the United States', 'Industrial Output', 'intcov_ratio', 'short_debt', 'at_turn', 'Equity Market Volatility Tracker: Overall', 'Total unit labor cost', 'pe_op_dil', 'Rent Inflation Rate', 'de_ratio', 'Coincident Economic Activity Index for the United States', 'Velocity of M2 Money Stock', 'pe_inc', 'gpm', 'aftret_eq', 'sale_invcap', 'pe_op_basic', 'Aggregate real person income (less transfer payment)', 'curr_ratio', 'sale_nwc', 'opmad', 'invt_act', 'Consumer Price Index (All Urban Items)', 'cash_debt', 'Imports of Goods and Services', 'dltt_be', 'opmbd', 'trt1m', 'rect_act_missing', 'Retail sales\xa0', 'M1', 'intcov_missing', 'quick_ratio_missing', 'inv_turn_missing', 'CAPEI', 'Food Inflation (Consumer Price Index for All Urban Consumers: Food in US City Average)', 'cash_ratio_missing', 'GProf', 'ptpm', 'pe_exi', 'sale_nwc_missing', 'University of Michigan: Consumer Sentiment', 'cash_conversion_missing', 'curr_debt', '4-Week Moving Average of Continued Claims', 'pretret_earnat_missing', 'profit_lct', 'Building permits for new private housing units ', 'Currency in Circulation', 'quick_ratio', 'Real Estate Loans: Residential Real Estate Loans: Revolving Home Equity Loans, All Commercial Banks', 'Employees on non-agricultural payrolls', 'cash_ratio']
#   (loss): QuantileLoss(quantiles=[0.02, 0.1, 0.25, 0.5, 0.75, 0.9, 0.98])
#   (logging_metrics): ModuleList(
#     (0): SMAPE()
#     (1): MAE()
#     (2): RMSE()
#     (3): MAPE()
#   )
#   (input_embeddings): MultiEmbedding(
#     (embeddings): ModuleDict()
#   )
#   (prescalers): ModuleDict(
#     (time_idx): Linear(in_features=1, out_features=8, bias=True)
#     (intcov): Linear(in_features=1, out_features=8, bias=True)
#     (PEG_trailing): Linear(in_features=1, out_features=8, bias=True)
#     (Auto Inventory/Sales Ratio): Linear(in_features=1, out_features=8, bias=True)
#     (sale_equity): Linear(in_features=1, out_features=8, bias=True)
#     (ocf_lct): Linear(in_features=1, out_features=8, bias=True)
#     (ocf_lct_missing): Linear(in_features=1, out_features=8, bias=True)
#     (pretret_noa): Linear(in_features=1, out_features=8, bias=True)
#     (Bank Credit, All Commercial Banks): Linear(in_features=1, out_features=8, bias=True)
#     (Export Price Index (End Use): All Commodities): Linear(in_features=1, out_features=8, bias=True)
#     (efftax): Linear(in_features=1, out_features=8, bias=True)
#     (Economic Policy Uncertainty Index for United States): Linear(in_features=1, out_features=8, bias=True)
#     (capital_ratio): Linear(in_features=1, out_features=8, bias=True)
#     (cshtrm): Linear(in_features=1, out_features=8, bias=True)
#     (debt_invcap): Linear(in_features=1, out_features=8, bias=True)
#     (Federal Government: Current Expenditures): Linear(in_features=1, out_features=8, bias=True)
#     (debt_capital): Linear(in_features=1, out_features=8, bias=True)
#     (Average Weeks Unemployed): Linear(in_features=1, out_features=8, bias=True)
#     (roce): Linear(in_features=1, out_features=8, bias=True)
#     (lt_debt): Linear(in_features=1, out_features=8, bias=True)
#     (pay_turn): Linear(in_features=1, out_features=8, bias=True)
#     (rect_turn): Linear(in_features=1, out_features=8, bias=True)
#     (lt_ppent): Linear(in_features=1, out_features=8, bias=True)
#     (pretret_earnat): Linear(in_features=1, out_features=8, bias=True)
#     (Sticky Consumer Price Index): Linear(in_features=1, out_features=8, bias=True)
#     (debt_assets): Linear(in_features=1, out_features=8, bias=True)
#     (rd_sale): Linear(in_features=1, out_features=8, bias=True)
#     (US dollar Index (Nominal Broad US Dollar Index)): Linear(in_features=1, out_features=8, bias=True)
#     (int_totdebt_missing): Linear(in_features=1, out_features=8, bias=True)
#     (Average weekly hours for manufacturing): Linear(in_features=1, out_features=8, bias=True)
#     (dpr): Linear(in_features=1, out_features=8, bias=True)
#     (staff_sale): Linear(in_features=1, out_features=8, bias=True)
#     (fcf_ocf): Linear(in_features=1, out_features=8, bias=True)
#     (pretret_noa_missing): Linear(in_features=1, out_features=8, bias=True)
#     (profit_lct_missing): Linear(in_features=1, out_features=8, bias=True)
#     (rect_act): Linear(in_features=1, out_features=8, bias=True)
#     (aftret_invcapx): Linear(in_features=1, out_features=8, bias=True)
#     (Manufacturers new orders for consumer goods and materials): Linear(in_features=1, out_features=8, bias=True)
#     (ps): Linear(in_features=1, out_features=8, bias=True)
#     (15-Year Fixed Rate Mortgage Average in the United States): Linear(in_features=1, out_features=8, bias=True)
#     (10-Year Treasury Constant Maturity Minus Federal Funds Rate): Linear(in_features=1, out_features=8, bias=True)
#     (roa): Linear(in_features=1, out_features=8, bias=True)
#     (US Public debt): Linear(in_features=1, out_features=8, bias=True)
#     (debt_ebitda): Linear(in_features=1, out_features=8, bias=True)
#     (US Population): Linear(in_features=1, out_features=8, bias=True)
#     (Labor Force Participation Rate): Linear(in_features=1, out_features=8, bias=True)
#     (roe): Linear(in_features=1, out_features=8, bias=True)
#     (evm): Linear(in_features=1, out_features=8, bias=True)
#     (Job Openings (Manufacturing)): Linear(in_features=1, out_features=8, bias=True)
#     (invt_act_missing): Linear(in_features=1, out_features=8, bias=True)
#     (aftret_equity): Linear(in_features=1, out_features=8, bias=True)
#     (intcov_ratio_missing): Linear(in_features=1, out_features=8, bias=True)
#     (CBOE Volatility Index (VIX)): Linear(in_features=1, out_features=8, bias=True)
#     (cfm): Linear(in_features=1, out_features=8, bias=True)
#     (US unemployment rate): Linear(in_features=1, out_features=8, bias=True)
#     (Producer Price Index by Industry (WPI)): Linear(in_features=1, out_features=8, bias=True)
#     (pcf): Linear(in_features=1, out_features=8, bias=True)
#     (Manufacturers new orders for non-defense capital goods): Linear(in_features=1, out_features=8, bias=True)
#     (cash_lt): Linear(in_features=1, out_features=8, bias=True)
#     (Federal Government Tax Income on Corporate): Linear(in_features=1, out_features=8, bias=True)
#     (Bank Prime Loan Rate): Linear(in_features=1, out_features=8, bias=True)
#     (cshoq): Linear(in_features=1, out_features=8, bias=True)
#     (Manufacturers Inventory/Sales Ratio): Linear(in_features=1, out_features=8, bias=True)
#     (Commercial and industrial loans outstanding): Linear(in_features=1, out_features=8, bias=True)
#     (Personal income tax): Linear(in_features=1, out_features=8, bias=True)
#     (bm): Linear(in_features=1, out_features=8, bias=True)
#     (int_debt_missing): Linear(in_features=1, out_features=8, bias=True)
#     (int_debt): Linear(in_features=1, out_features=8, bias=True)
#     (npm): Linear(in_features=1, out_features=8, bias=True)
#     (Weekly Economic Index (Lewis-Mertens-Stock)): Linear(in_features=1, out_features=8, bias=True)
#     (US GDP Growth Rate): Linear(in_features=1, out_features=8, bias=True)
#     (debt_at): Linear(in_features=1, out_features=8, bias=True)
#     (totdebt_invcap): Linear(in_features=1, out_features=8, bias=True)
#     (Security Brokers and Dealers; Margin Accounts at Brokers and Dealers; Asset, Level): Linear(in_features=1, out_features=8, bias=True)
#     (Energy Inflation (Consumer Price Index for All Urban Consumers: Energy in US City Average)): Linear(in_features=1, out_features=8, bias=True)
#     (adv_sale): Linear(in_features=1, out_features=8, bias=True)
#     (M2): Linear(in_features=1, out_features=8, bias=True)
#     (ptb): Linear(in_features=1, out_features=8, bias=True)
#     (Loan Performance: Total Loans and Leases: Noncurrent Rate): Linear(in_features=1, out_features=8, bias=True)
#     (Interest Rates): Linear(in_features=1, out_features=8, bias=True)
#     (curr_ratio_missing): Linear(in_features=1, out_features=8, bias=True)
#     (inv_turn): Linear(in_features=1, out_features=8, bias=True)
#     (accrual): Linear(in_features=1, out_features=8, bias=True)
#     (divyield): Linear(in_features=1, out_features=8, bias=True)
#     (Average Weekly Hours of Production and Nonsupervisory Employees, Manufacturing): Linear(in_features=1, out_features=8, bias=True)
#     (equity_invcap): Linear(in_features=1, out_features=8, bias=True)
#     (curr_debt_missing): Linear(in_features=1, out_features=8, bias=True)
#     (Federal government current tax receipts): Linear(in_features=1, out_features=8, bias=True)
#     (Call Money/Interbank Rate for the United States): Linear(in_features=1, out_features=8, bias=True)
#     (Industrial Output): Linear(in_features=1, out_features=8, bias=True)
#     (intcov_ratio): Linear(in_features=1, out_features=8, bias=True)
#     (short_debt): Linear(in_features=1, out_features=8, bias=True)
#     (at_turn): Linear(in_features=1, out_features=8, bias=True)
#     (Equity Market Volatility Tracker: Overall): Linear(in_features=1, out_features=8, bias=True)
#     (Total unit labor cost): Linear(in_features=1, out_features=8, bias=True)
#     (pe_op_dil): Linear(in_features=1, out_features=8, bias=True)
#     (Rent Inflation Rate): Linear(in_features=1, out_features=8, bias=True)
#     (de_ratio): Linear(in_features=1, out_features=8, bias=True)
#     (Coincident Economic Activity Index for the United States): Linear(in_features=1, out_features=8, bias=True)
#     (Velocity of M2 Money Stock): Linear(in_features=1, out_features=8, bias=True)
#     (pe_inc): Linear(in_features=1, out_features=8, bias=True)
#     (gpm): Linear(in_features=1, out_features=8, bias=True)
#     (aftret_eq): Linear(in_features=1, out_features=8, bias=True)
#     (sale_invcap): Linear(in_features=1, out_features=8, bias=True)
#     (pe_op_basic): Linear(in_features=1, out_features=8, bias=True)
#     (Aggregate real person income (less transfer payment)): Linear(in_features=1, out_features=8, bias=True)
#     (curr_ratio): Linear(in_features=1, out_features=8, bias=True)
#     (sale_nwc): Linear(in_features=1, out_features=8, bias=True)
#     (opmad): Linear(in_features=1, out_features=8, bias=True)
#     (invt_act): Linear(in_features=1, out_features=8, bias=True)
#     (Consumer Price Index (All Urban Items)): Linear(in_features=1, out_features=8, bias=True)
#     (cash_debt): Linear(in_features=1, out_features=8, bias=True)
#     (Imports of Goods and Services): Linear(in_features=1, out_features=8, bias=True)
#     (dltt_be): Linear(in_features=1, out_features=8, bias=True)
#     (opmbd): Linear(in_features=1, out_features=8, bias=True)
#     (trt1m): Linear(in_features=1, out_features=8, bias=True)
#     (rect_act_missing): Linear(in_features=1, out_features=8, bias=True)
#     (Retail sales ): Linear(in_features=1, out_features=8, bias=True)
#     (M1): Linear(in_features=1, out_features=8, bias=True)
#     (intcov_missing): Linear(in_features=1, out_features=8, bias=True)
#     (quick_ratio_missing): Linear(in_features=1, out_features=8, bias=True)
#     (inv_turn_missing): Linear(in_features=1, out_features=8, bias=True)
#     (CAPEI): Linear(in_features=1, out_features=8, bias=True)
#     (Food Inflation (Consumer Price Index for All Urban Consumers: Food in US City Average)): Linear(in_features=1, out_features=8, bias=True)
#     (cash_ratio_missing): Linear(in_features=1, out_features=8, bias=True)
#     (GProf): Linear(in_features=1, out_features=8, bias=True)
#     (ptpm): Linear(in_features=1, out_features=8, bias=True)
#     (pe_exi): Linear(in_features=1, out_features=8, bias=True)
#     (sale_nwc_missing): Linear(in_features=1, out_features=8, bias=True)
#     (University of Michigan: Consumer Sentiment): Linear(in_features=1, out_features=8, bias=True)
#     (cash_conversion_missing): Linear(in_features=1, out_features=8, bias=True)
#     (curr_debt): Linear(in_features=1, out_features=8, bias=True)
#     (4-Week Moving Average of Continued Claims): Linear(in_features=1, out_features=8, bias=True)
#     (pretret_earnat_missing): Linear(in_features=1, out_features=8, bias=True)
#     (profit_lct): Linear(in_features=1, out_features=8, bias=True)
#     (Building permits for new private housing units ): Linear(in_features=1, out_features=8, bias=True)
#     (Currency in Circulation): Linear(in_features=1, out_features=8, bias=True)
#     (quick_ratio): Linear(in_features=1, out_features=8, bias=True)
#     (Real Estate Loans: Residential Real Estate Loans: Revolving Home Equity Loans, All Commercial Banks): Linear(in_features=1, out_features=8, bias=True)
#     (Employees on non-agricultural payrolls): Linear(in_features=1, out_features=8, bias=True)
#     (cash_ratio): Linear(in_features=1, out_features=8, bias=True)
#   )
#   (static_variable_selection): VariableSelectionNetwork(
#     (single_variable_grns): ModuleDict()
#     (prescalers): ModuleDict()
#     (softmax): Softmax(dim=-1)
#   )
#   (encoder_variable_selection): VariableSelectionNetwork(
#     (flattened_grn): GatedResidualNetwork(
#       (resample_norm): ResampleNorm(
#         (resample): TimeDistributedInterpolation()
#         (gate): Sigmoid()
#         (norm): LayerNorm((141,), eps=1e-05, elementwise_affine=True)
#       )
#       (fc1): Linear(in_features=1128, out_features=16, bias=True)
#       (elu): ELU(alpha=1.0)
#       (context): Linear(in_features=16, out_features=16, bias=False)
#       (fc2): Linear(in_features=16, out_features=16, bias=True)
#       (gate_norm): GateAddNorm(
#         (glu): GatedLinearUnit(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (fc): Linear(in_features=16, out_features=282, bias=True)
#         )
#         (add_norm): AddNorm(
#           (norm): LayerNorm((141,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (single_variable_grns): ModuleDict(
#       (time_idx): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (intcov): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (PEG_trailing): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (Auto Inventory/Sales Ratio): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (sale_equity): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (ocf_lct): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (ocf_lct_missing): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (pretret_noa): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (Bank Credit, All Commercial Banks): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (Export Price Index (End Use): All Commodities): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (efftax): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (Economic Policy Uncertainty Index for United States): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (capital_ratio): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (cshtrm): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (debt_invcap): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (Federal Government: Current Expenditures): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (debt_capital): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (Average Weeks Unemployed): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (roce): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (lt_debt): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (pay_turn): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (rect_turn): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (lt_ppent): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (pretret_earnat): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (Sticky Consumer Price Index): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (debt_assets): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (rd_sale): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (US dollar Index (Nominal Broad US Dollar Index)): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (int_totdebt_missing): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (Average weekly hours for manufacturing): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (dpr): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (staff_sale): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (fcf_ocf): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (pretret_noa_missing): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (profit_lct_missing): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (rect_act): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (aftret_invcapx): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
# ...
#       (debt_invcap): Linear(in_features=1, out_features=8, bias=True)
#       (Federal Government: Current Expenditures): Linear(in_features=1, out_features=8, bias=True)
#       (debt_capital): Linear(in_features=1, out_features=8, bias=True)
#       (Average Weeks Unemployed): Linear(in_features=1, out_features=8, bias=True)
#       (roce): Linear(in_features=1, out_features=8, bias=True)
#       (lt_debt): Linear(in_features=1, out_features=8, bias=True)
#       (pay_turn): Linear(in_features=1, out_features=8, bias=True)
#       (rect_turn): Linear(in_features=1, out_features=8, bias=True)
#       (lt_ppent): Linear(in_features=1, out_features=8, bias=True)
#       (pretret_earnat): Linear(in_features=1, out_features=8, bias=True)
#       (Sticky Consumer Price Index): Linear(in_features=1, out_features=8, bias=True)
#       (debt_assets): Linear(in_features=1, out_features=8, bias=True)
#       (rd_sale): Linear(in_features=1, out_features=8, bias=True)
#       (US dollar Index (Nominal Broad US Dollar Index)): Linear(in_features=1, out_features=8, bias=True)
#       (int_totdebt_missing): Linear(in_features=1, out_features=8, bias=True)
#       (Average weekly hours for manufacturing): Linear(in_features=1, out_features=8, bias=True)
#       (dpr): Linear(in_features=1, out_features=8, bias=True)
#       (staff_sale): Linear(in_features=1, out_features=8, bias=True)
#       (fcf_ocf): Linear(in_features=1, out_features=8, bias=True)
#       (pretret_noa_missing): Linear(in_features=1, out_features=8, bias=True)
#       (profit_lct_missing): Linear(in_features=1, out_features=8, bias=True)
#       (rect_act): Linear(in_features=1, out_features=8, bias=True)
#       (aftret_invcapx): Linear(in_features=1, out_features=8, bias=True)
#       (Manufacturers new orders for consumer goods and materials): Linear(in_features=1, out_features=8, bias=True)
#       (ps): Linear(in_features=1, out_features=8, bias=True)
#       (15-Year Fixed Rate Mortgage Average in the United States): Linear(in_features=1, out_features=8, bias=True)
#       (10-Year Treasury Constant Maturity Minus Federal Funds Rate): Linear(in_features=1, out_features=8, bias=True)
#       (roa): Linear(in_features=1, out_features=8, bias=True)
#       (US Public debt): Linear(in_features=1, out_features=8, bias=True)
#       (debt_ebitda): Linear(in_features=1, out_features=8, bias=True)
#       (US Population): Linear(in_features=1, out_features=8, bias=True)
#       (Labor Force Participation Rate): Linear(in_features=1, out_features=8, bias=True)
#       (roe): Linear(in_features=1, out_features=8, bias=True)
#       (evm): Linear(in_features=1, out_features=8, bias=True)
#       (Job Openings (Manufacturing)): Linear(in_features=1, out_features=8, bias=True)
#       (invt_act_missing): Linear(in_features=1, out_features=8, bias=True)
#       (aftret_equity): Linear(in_features=1, out_features=8, bias=True)
#       (intcov_ratio_missing): Linear(in_features=1, out_features=8, bias=True)
#       (CBOE Volatility Index (VIX)): Linear(in_features=1, out_features=8, bias=True)
#       (cfm): Linear(in_features=1, out_features=8, bias=True)
#       (US unemployment rate): Linear(in_features=1, out_features=8, bias=True)
#       (Producer Price Index by Industry (WPI)): Linear(in_features=1, out_features=8, bias=True)
#       (pcf): Linear(in_features=1, out_features=8, bias=True)
#       (Manufacturers new orders for non-defense capital goods): Linear(in_features=1, out_features=8, bias=True)
#       (cash_lt): Linear(in_features=1, out_features=8, bias=True)
#       (Federal Government Tax Income on Corporate): Linear(in_features=1, out_features=8, bias=True)
#       (Bank Prime Loan Rate): Linear(in_features=1, out_features=8, bias=True)
#       (cshoq): Linear(in_features=1, out_features=8, bias=True)
#       (Manufacturers Inventory/Sales Ratio): Linear(in_features=1, out_features=8, bias=True)
#       (Commercial and industrial loans outstanding): Linear(in_features=1, out_features=8, bias=True)
#       (Personal income tax): Linear(in_features=1, out_features=8, bias=True)
#       (bm): Linear(in_features=1, out_features=8, bias=True)
#       (int_debt_missing): Linear(in_features=1, out_features=8, bias=True)
#       (int_debt): Linear(in_features=1, out_features=8, bias=True)
#       (npm): Linear(in_features=1, out_features=8, bias=True)
#       (Weekly Economic Index (Lewis-Mertens-Stock)): Linear(in_features=1, out_features=8, bias=True)
#       (US GDP Growth Rate): Linear(in_features=1, out_features=8, bias=True)
#       (debt_at): Linear(in_features=1, out_features=8, bias=True)
#       (totdebt_invcap): Linear(in_features=1, out_features=8, bias=True)
#       (Security Brokers and Dealers; Margin Accounts at Brokers and Dealers; Asset, Level): Linear(in_features=1, out_features=8, bias=True)
#       (Energy Inflation (Consumer Price Index for All Urban Consumers: Energy in US City Average)): Linear(in_features=1, out_features=8, bias=True)
#       (adv_sale): Linear(in_features=1, out_features=8, bias=True)
#       (M2): Linear(in_features=1, out_features=8, bias=True)
#       (ptb): Linear(in_features=1, out_features=8, bias=True)
#       (Loan Performance: Total Loans and Leases: Noncurrent Rate): Linear(in_features=1, out_features=8, bias=True)
#       (Interest Rates): Linear(in_features=1, out_features=8, bias=True)
#       (curr_ratio_missing): Linear(in_features=1, out_features=8, bias=True)
#       (inv_turn): Linear(in_features=1, out_features=8, bias=True)
#       (accrual): Linear(in_features=1, out_features=8, bias=True)
#       (divyield): Linear(in_features=1, out_features=8, bias=True)
#       (Average Weekly Hours of Production and Nonsupervisory Employees, Manufacturing): Linear(in_features=1, out_features=8, bias=True)
#       (equity_invcap): Linear(in_features=1, out_features=8, bias=True)
#       (curr_debt_missing): Linear(in_features=1, out_features=8, bias=True)
#       (Federal government current tax receipts): Linear(in_features=1, out_features=8, bias=True)
#       (Call Money/Interbank Rate for the United States): Linear(in_features=1, out_features=8, bias=True)
#       (Industrial Output): Linear(in_features=1, out_features=8, bias=True)
#       (intcov_ratio): Linear(in_features=1, out_features=8, bias=True)
#       (short_debt): Linear(in_features=1, out_features=8, bias=True)
#       (at_turn): Linear(in_features=1, out_features=8, bias=True)
#       (Equity Market Volatility Tracker: Overall): Linear(in_features=1, out_features=8, bias=True)
#       (Total unit labor cost): Linear(in_features=1, out_features=8, bias=True)
#       (pe_op_dil): Linear(in_features=1, out_features=8, bias=True)
#       (Rent Inflation Rate): Linear(in_features=1, out_features=8, bias=True)
#       (de_ratio): Linear(in_features=1, out_features=8, bias=True)
#       (Coincident Economic Activity Index for the United States): Linear(in_features=1, out_features=8, bias=True)
#       (Velocity of M2 Money Stock): Linear(in_features=1, out_features=8, bias=True)
#       (pe_inc): Linear(in_features=1, out_features=8, bias=True)
#       (gpm): Linear(in_features=1, out_features=8, bias=True)
#       (aftret_eq): Linear(in_features=1, out_features=8, bias=True)
#       (sale_invcap): Linear(in_features=1, out_features=8, bias=True)
#       (pe_op_basic): Linear(in_features=1, out_features=8, bias=True)
#       (Aggregate real person income (less transfer payment)): Linear(in_features=1, out_features=8, bias=True)
#       (curr_ratio): Linear(in_features=1, out_features=8, bias=True)
#       (sale_nwc): Linear(in_features=1, out_features=8, bias=True)
#       (opmad): Linear(in_features=1, out_features=8, bias=True)
#       (invt_act): Linear(in_features=1, out_features=8, bias=True)
#       (Consumer Price Index (All Urban Items)): Linear(in_features=1, out_features=8, bias=True)
#       (cash_debt): Linear(in_features=1, out_features=8, bias=True)
#       (Imports of Goods and Services): Linear(in_features=1, out_features=8, bias=True)
#       (dltt_be): Linear(in_features=1, out_features=8, bias=True)
#       (opmbd): Linear(in_features=1, out_features=8, bias=True)
#       (trt1m): Linear(in_features=1, out_features=8, bias=True)
#       (rect_act_missing): Linear(in_features=1, out_features=8, bias=True)
#       (Retail sales ): Linear(in_features=1, out_features=8, bias=True)
#       (M1): Linear(in_features=1, out_features=8, bias=True)
#       (intcov_missing): Linear(in_features=1, out_features=8, bias=True)
#       (quick_ratio_missing): Linear(in_features=1, out_features=8, bias=True)
#       (inv_turn_missing): Linear(in_features=1, out_features=8, bias=True)
#       (CAPEI): Linear(in_features=1, out_features=8, bias=True)
#       (Food Inflation (Consumer Price Index for All Urban Consumers: Food in US City Average)): Linear(in_features=1, out_features=8, bias=True)
#       (cash_ratio_missing): Linear(in_features=1, out_features=8, bias=True)
#       (GProf): Linear(in_features=1, out_features=8, bias=True)
#       (ptpm): Linear(in_features=1, out_features=8, bias=True)
#       (pe_exi): Linear(in_features=1, out_features=8, bias=True)
#       (sale_nwc_missing): Linear(in_features=1, out_features=8, bias=True)
#       (University of Michigan: Consumer Sentiment): Linear(in_features=1, out_features=8, bias=True)
#       (cash_conversion_missing): Linear(in_features=1, out_features=8, bias=True)
#       (curr_debt): Linear(in_features=1, out_features=8, bias=True)
#       (4-Week Moving Average of Continued Claims): Linear(in_features=1, out_features=8, bias=True)
#       (pretret_earnat_missing): Linear(in_features=1, out_features=8, bias=True)
#       (profit_lct): Linear(in_features=1, out_features=8, bias=True)
#       (Building permits for new private housing units ): Linear(in_features=1, out_features=8, bias=True)
#       (Currency in Circulation): Linear(in_features=1, out_features=8, bias=True)
#       (quick_ratio): Linear(in_features=1, out_features=8, bias=True)
#       (Real Estate Loans: Residential Real Estate Loans: Revolving Home Equity Loans, All Commercial Banks): Linear(in_features=1, out_features=8, bias=True)
#       (Employees on non-agricultural payrolls): Linear(in_features=1, out_features=8, bias=True)
#       (cash_ratio): Linear(in_features=1, out_features=8, bias=True)
#     )
#     (softmax): Softmax(dim=-1)
#   )
#   (decoder_variable_selection): VariableSelectionNetwork(
#     (single_variable_grns): ModuleDict(
#       (time_idx): GatedResidualNetwork(
#         (resample_norm): ResampleNorm(
#           (resample): TimeDistributedInterpolation()
#           (gate): Sigmoid()
#           (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#         )
#         (fc1): Linear(in_features=8, out_features=8, bias=True)
#         (elu): ELU(alpha=1.0)
#         (fc2): Linear(in_features=8, out_features=8, bias=True)
#         (gate_norm): GateAddNorm(
#           (glu): GatedLinearUnit(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (fc): Linear(in_features=8, out_features=32, bias=True)
#           )
#           (add_norm): AddNorm(
#             (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (prescalers): ModuleDict(
#       (time_idx): Linear(in_features=1, out_features=8, bias=True)
#     )
#     (softmax): Softmax(dim=-1)
#   )
#   (static_context_variable_selection): GatedResidualNetwork(
#     (fc1): Linear(in_features=16, out_features=16, bias=True)
#     (elu): ELU(alpha=1.0)
#     (fc2): Linear(in_features=16, out_features=16, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.1, inplace=False)
#         (fc): Linear(in_features=16, out_features=32, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (static_context_initial_hidden_lstm): GatedResidualNetwork(
#     (fc1): Linear(in_features=16, out_features=16, bias=True)
#     (elu): ELU(alpha=1.0)
#     (fc2): Linear(in_features=16, out_features=16, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.1, inplace=False)
#         (fc): Linear(in_features=16, out_features=32, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (static_context_initial_cell_lstm): GatedResidualNetwork(
#     (fc1): Linear(in_features=16, out_features=16, bias=True)
#     (elu): ELU(alpha=1.0)
#     (fc2): Linear(in_features=16, out_features=16, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.1, inplace=False)
#         (fc): Linear(in_features=16, out_features=32, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (static_context_enrichment): GatedResidualNetwork(
#     (fc1): Linear(in_features=16, out_features=16, bias=True)
#     (elu): ELU(alpha=1.0)
#     (fc2): Linear(in_features=16, out_features=16, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.1, inplace=False)
#         (fc): Linear(in_features=16, out_features=32, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (lstm_encoder): LSTM(16, 16, batch_first=True)
#   (lstm_decoder): LSTM(16, 16, batch_first=True)
#   (post_lstm_gate_encoder): GatedLinearUnit(
#     (dropout): Dropout(p=0.1, inplace=False)
#     (fc): Linear(in_features=16, out_features=32, bias=True)
#   )
#   (post_lstm_gate_decoder): GatedLinearUnit(
#     (dropout): Dropout(p=0.1, inplace=False)
#     (fc): Linear(in_features=16, out_features=32, bias=True)
#   )
#   (post_lstm_add_norm_encoder): AddNorm(
#     (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#   )
#   (post_lstm_add_norm_decoder): AddNorm(
#     (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#   )
#   (static_enrichment): GatedResidualNetwork(
#     (fc1): Linear(in_features=16, out_features=16, bias=True)
#     (elu): ELU(alpha=1.0)
#     (context): Linear(in_features=16, out_features=16, bias=False)
#     (fc2): Linear(in_features=16, out_features=16, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.1, inplace=False)
#         (fc): Linear(in_features=16, out_features=32, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (multihead_attn): InterpretableMultiHeadAttention(
#     (dropout): Dropout(p=0.1, inplace=False)
#     (v_layer): Linear(in_features=16, out_features=16, bias=True)
#     (q_layers): ModuleList(
#       (0): Linear(in_features=16, out_features=16, bias=True)
#     )
#     (k_layers): ModuleList(
#       (0): Linear(in_features=16, out_features=16, bias=True)
#     )
#     (attention): ScaledDotProductAttention(
#       (softmax): Softmax(dim=2)
#     )
#     (w_h): Linear(in_features=16, out_features=16, bias=False)
#   )
#   (post_attn_gate_norm): GateAddNorm(
#     (glu): GatedLinearUnit(
#       (dropout): Dropout(p=0.1, inplace=False)
#       (fc): Linear(in_features=16, out_features=32, bias=True)
#     )
#     (add_norm): AddNorm(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (pos_wise_ff): GatedResidualNetwork(
#     (fc1): Linear(in_features=16, out_features=16, bias=True)
#     (elu): ELU(alpha=1.0)
#     (fc2): Linear(in_features=16, out_features=16, bias=True)
#     (gate_norm): GateAddNorm(
#       (glu): GatedLinearUnit(
#         (dropout): Dropout(p=0.1, inplace=False)
#         (fc): Linear(in_features=16, out_features=32, bias=True)
#       )
#       (add_norm): AddNorm(
#         (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (pre_output_gate_norm): GateAddNorm(
#     (glu): GatedLinearUnit(
#       (fc): Linear(in_features=16, out_features=32, bias=True)
#     )
#     (add_norm): AddNorm(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (output_layer): Linear(in_features=16, out_features=7, bias=True)
# )

# %%
# raw predictions are a dictionary from which all kind of information including quantiles can be extracted
raw_predictions, x = tft.predict(testing_dataloader2, mode="raw", return_x=True)

# %%
interpretation = tft.interpret_output(raw_predictions, reduction="sum")
tft.plot_interpretation(interpretation)
# Out:
# {'attention': <Figure size 640x480 with 1 Axes>,
#  'static_variables': <Figure size 700x200 with 1 Axes>,
#  'encoder_variables': <Figure size 700x3725 with 1 Axes>,
#  'decoder_variables': <Figure size 700x225 with 1 Axes>}

# %%
len(tft.encoder_variables)
# Out:
# 141

# %%
interpretation['encoder_variables']
# Out:
# tensor([2.7153e+01, 1.6016e+01, 3.2839e+01, 1.2825e+01, 1.5019e+01, 3.1249e+01,
#         4.1956e+01, 2.8373e+01, 1.8681e+01, 2.5888e+01, 2.2953e+01, 2.2445e+01,
#         3.1185e+01, 9.3600e+00, 3.3023e+01, 1.4046e+01, 1.7330e+01, 1.1632e+02,
#         6.4945e+00, 3.1127e+01, 2.1963e+01, 1.5258e+02, 3.4361e+01, 2.1510e+01,
#         2.9733e+01, 2.3841e+01, 1.5898e+01, 1.4919e+01, 2.9895e+01, 7.8494e+00,
#         3.4474e+01, 3.0094e+01, 1.1634e+01, 4.1190e+02, 4.0372e+01, 1.9343e+01,
#         2.0499e+01, 2.1730e+01, 2.9793e+01, 3.6727e+01, 2.2820e+01, 1.2735e+01,
#         2.5378e+01, 1.1257e+01, 3.2415e+01, 3.6262e+01, 2.2600e+01, 1.7874e+01,
#         4.1136e+01, 2.1877e+01, 8.1817e+00, 1.4327e+02, 5.5935e+01, 1.8178e+02,
#         2.3169e+01, 2.3389e+01, 1.2597e+02, 3.8259e+01, 1.0380e+01, 2.3641e+01,
#         1.1917e+01, 8.6704e+01, 3.8402e+01, 3.5029e+01, 1.1034e+01, 2.1841e+01,
#         1.7098e+01, 4.5330e+01, 1.5012e+01, 4.0597e+01, 2.3117e+01, 1.7554e+01,
#         4.8977e+01, 3.2406e+01, 2.2253e+01, 1.8133e+01, 2.8478e+02, 5.2951e+00,
#         2.5404e+01, 4.3026e+01, 2.3759e+01, 3.6432e+02, 4.6914e+01, 1.4647e+01,
#         4.9092e+01, 2.4750e+01, 3.0834e+01, 9.2545e+00, 3.1525e+01, 2.6211e+01,
#         2.5397e+01, 5.4309e+01, 5.7526e+01, 2.6822e+01, 6.1385e+01, 1.5665e+01,
#         3.8560e+01, 4.2048e+01, 5.8169e+01, 1.9525e+01, 9.7053e+00, 3.2309e+01,
#         1.8807e+02, 2.2989e+01, 2.6648e+01, 2.7193e+01, 2.2097e+01, 1.9000e+00,
#         2.2156e+01, 1.3447e+01, 3.5071e+01, 5.3703e+02, 7.4195e+01, 3.0106e+01,
#         5.0009e+01, 3.8168e+01, 3.3607e+01, 2.2254e+01, 4.0382e+01, 1.9894e+02,
#         1.5935e+01, 4.3987e+00, 1.8680e+04, 3.5834e+01, 8.3882e+01, 2.0523e+01,
#         3.9122e+01, 2.0216e+01, 1.2344e+01, 6.0154e+01, 2.8842e+01, 1.4511e+01,
#         1.2164e+02, 2.9349e+01, 9.8234e+01, 2.7542e+01, 3.0560e+01, 3.3595e+01,
#         1.5190e+01, 3.1259e+01, 1.0126e+02])

# %%
feature_importance = pd.DataFrame({'factor_trt1m':tft.encoder_variables, 'coefficient_trt1m':interpretation['encoder_variables']})

# %%
feature_importance = feature_importance.sort_values(by='coefficient_trt1m', ascending=False)
feature_importance
# Out:
#                                factor_trt1m  coefficient_trt1m
# 122                                   CAPEI       18679.980469
# 111                               cash_debt         537.028137
# 33                      pretret_noa_missing         411.903595
# 81                                 inv_turn         364.322296
# 76                                       M2         284.780701
# ..                                      ...                ...
# 29   Average weekly hours for manufacturing           7.849426
# 18                                     roce           6.494546
# 77                                      ptb           5.295138
# 121                        inv_turn_missing           4.398710
# 107                                sale_nwc           1.899968
#
# [141 rows x 2 columns]

# %%
feature_importance.to_csv("TFT Feature Importance.csv", index=False)

# %%
data_60=data_prior2014[data_prior2014['gvkey'].isin(train_set['gvkey'])]
data_40=data_prior2014[data_prior2014['gvkey'].isin(valid_set['gvkey'])]

# %%
gvkeys = data_60['gvkey'].unique()

# Randomly select 30 elements from the array
random_indices = np.random.choice(gvkeys.shape[0], size=100, replace=False)
samples = gvkeys[random_indices]
# Create a sub-DataFrame containing only rows where gvkeys is in selected_elements
sample_df = data_60[data_60['gvkey'].isin(samples)]

training_data_sample = TimeSeriesDataSet(
    sample_df,
    time_idx="time_idx",
    target="trt1m",
    group_ids=["gvkey"],
    time_varying_unknown_reals= col_list,
    max_encoder_length=n_time_steps,
    max_prediction_length=n_predictions,
    allow_missing_timesteps=True,
    time_varying_known_reals=["time_idx"]
)

train_dataloader_sample  = training_data_sample.to_dataloader(train=True, batch_size=batch_size, num_workers=5)

# %%
gvkeys4 = data_40['gvkey'].unique()

# Randomly select 30 elements from the array
random_indices4 = np.random.choice(gvkeys4.shape[0], size=50, replace=False)
samples4 = gvkeys4[random_indices4]
# Create a sub-DataFrame containing only rows where gvkeys is in selected_elements
sample_df4 = data_40[data_40['gvkey'].isin(samples4)]

vali_data_sample = TimeSeriesDataSet(
    sample_df4,
    time_idx="time_idx",
    target="trt1m",
    group_ids=["gvkey"],
    time_varying_unknown_reals= col_list,
    max_encoder_length=n_time_steps,
    max_prediction_length=n_predictions,
    allow_missing_timesteps=True,
    time_varying_known_reals=["time_idx"]
)

vali_dataloader_sample  = vali_data_sample.to_dataloader(train=False, batch_size=batch_size, num_workers=5)

# %%
import pickle

from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

# create study
study = optimize_hyperparameters(
    train_dataloader_sample,
    vali_dataloader_sample,
    model_path="optuna_test",
    n_trials=50,  
    max_epochs=20,  
    gradient_clip_val_range=(0.01, 0.1),  
    hidden_size_range=(8, 32),  
    hidden_continuous_size_range=(8, 32),  
    attention_head_size_range=(1, 2),  
    learning_rate_range=(0.001, 0.01),  
    dropout_range=(0.1, 0.2),  
    trainer_kwargs=dict(limit_train_batches=10),  
    reduce_on_plateau_patience=2,  
    use_learning_rate_finder=False, 
)

with open("test_study.pkl", "wb") as fout:
    pickle.dump(study, fout)

print(study.best_trial.params)
# Out:
# [I 2023-04-12 02:58:21,851] A new study created in memory with name: no-name-2142aa9d-50c0-434e-a8b3-1e65ed41aa55
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2023-04-12 03:08:20,961] Trial 0 finished with value: 4.29507303237915 and parameters: {'gradient_clip_val': 0.015247085241691482, 'hidden_size': 9, 'dropout': 0.10734221332036537, 'hidden_continuous_size': 8, 'attention_head_size': 1, 'learning_rate': 0.0026767894761904314}. Best is trial 0 with value: 4.29507303237915.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2023-04-12 03:18:43,829] Trial 1 finished with value: 4.779044151306152 and parameters: {'gradient_clip_val': 0.02114370155478029, 'hidden_size': 11, 'dropout': 0.13305091335912123, 'hidden_continuous_size': 10, 'attention_head_size': 1, 'learning_rate': 0.0010723699492029698}. Best is trial 0 with value: 4.29507303237915.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2023-04-12 03:28:23,218] Trial 2 finished with value: 4.343416213989258 and parameters: {'gradient_clip_val': 0.07624077758778856, 'hidden_size': 10, 'dropout': 0.11144363363752141, 'hidden_continuous_size': 10, 'attention_head_size': 1, 'learning_rate': 0.0017560562152029702}. Best is trial 0 with value: 4.29507303237915.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer.fit` stopped: `max_epochs=20` reached.
# [I 2023-04-12 03:39:49,475] Trial 3 finished with value: 4.1313371658325195 and parameters: {'gradient_clip_val': 0.01272237211105487, 'hidden_size': 16, 'dropout': 0.15061087870498097, 'hidden_continuous_size': 14, 'attention_head_size': 2, 'learning_rate': 0.0025959579657758173}. Best is trial 3 with value: 4.1313371658325195.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:41:05,833] Trial 4 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:42:35,478] Trial 5 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:44:15,600] Trial 6 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:45:26,466] Trial 7 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:47:36,374] Trial 8 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:48:48,425] Trial 9 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:50:59,923] Trial 10 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:52:41,705] Trial 11 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:54:00,421] Trial 12 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:55:57,485] Trial 13 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:57:15,448] Trial 14 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 03:59:18,851] Trial 15 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:01:02,714] Trial 16 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:04:00,341] Trial 17 pruned. Trial was pruned at epoch 4.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:05:40,909] Trial 18 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:06:52,885] Trial 19 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:09:03,771] Trial 20 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:10:39,067] Trial 21 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:11:48,397] Trial 22 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:14:04,061] Trial 23 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:15:16,876] Trial 24 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:17:27,162] Trial 25 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:19:06,108] Trial 26 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:20:12,602] Trial 27 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:23:46,650] Trial 28 pruned. Trial was pruned at epoch 4.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:26:57,387] Trial 29 pruned. Trial was pruned at epoch 4.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:29:50,396] Trial 30 pruned. Trial was pruned at epoch 4.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:31:02,637] Trial 31 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:33:06,596] Trial 32 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:34:46,640] Trial 33 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:43:23,335] Trial 34 pruned. Trial was pruned at epoch 16.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:45:03,125] Trial 35 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:46:21,223] Trial 36 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:48:17,526] Trial 37 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:49:35,543] Trial 38 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:51:38,067] Trial 39 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:53:14,073] Trial 40 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:54:23,348] Trial 41 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:56:21,504] Trial 42 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:57:30,960] Trial 43 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 04:59:36,659] Trial 44 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 05:00:41,602] Trial 45 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 05:02:48,505] Trial 46 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 05:04:31,073] Trial 47 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 05:05:38,523] Trial 48 pruned. Trial was pruned at epoch 1.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [I 2023-04-12 05:07:39,224] Trial 49 pruned. Trial was pruned at epoch 1.
# {'gradient_clip_val': 0.01272237211105487, 'hidden_size': 16, 'dropout': 0.15061087870498097, 'hidden_continuous_size': 14, 'attention_head_size': 2, 'learning_rate': 0.0025959579657758173}

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)
actuals = torch.cat([y[0] for x, y in iter(testing_dataloader)])
predictions = best_tft.predict(testing_dataloader)
mean_squared_error(actuals,predictions)

# %%
# load the best model according to the validation loss
# (given that we use early stopping, this is not necessarily the last epoch)
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)
# calcualte mean absolute error on validation set
actuals = torch.cat([y[0] for x, y in iter(testing_dataloader)])
predictions = best_tft.predict(testing_dataloader)
(actuals - predictions).abs().mean()

# %%
tft = TemporalFusionTransformer.from_dataset(
    time_series,
    # not meaningful for finding the learning rate but otherwise very important
    learning_rate=0.03,
    hidden_size=16,  # most important hyperparameter apart from learning rate
    # number of attention heads. Set to up to 4 for large datasets
    attention_head_size=1,
    dropout=0.1,  # between 0.1 and 0.3 are good values
    hidden_continuous_size=8,  # set to <= hidden_size
    output_size=7,  # 7 quantiles by default
    loss=QuantileLoss(),
    # reduce learning rate if no improvement in validation loss after x epochs
    reduce_on_plateau_patience=4,
)
# Out:
# /usr/local/lib/python3.9/dist-packages/pytorch_lightning/utilities/parsing.py:269: UserWarning: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
#   rank_zero_warn(
# /usr/local/lib/python3.9/dist-packages/pytorch_lightning/utilities/parsing.py:269: UserWarning: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
#   rank_zero_warn(
