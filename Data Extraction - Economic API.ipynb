# %% [markdown]
# # Non-farm employment

# %%
pip install -U pandasql
# Out:
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=17425263ca281a84805e5dab2d52445081d5afbfde53bf76d2993ba583d706a7
#   Stored in directory: /Users/xiaoyuzhu/Library/Caches/pip/wheels/63/e8/ec/75b1df467ecf57b6ececb32cb16f4e86697cbfe55cb0c51f07
# Successfully built pandasql
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandasql
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
from fredapi import Fred
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('PAYEMS') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-03-01    150856.0
# 2022-04-01    151224.0
# 2022-05-01    151610.0
# 2022-06-01    151903.0
# 2022-07-01    152440.0
# 2022-08-01    152732.0
# 2022-09-01    153001.0
# 2022-10-01    153264.0
# 2022-11-01    153520.0
# 2022-12-01    153743.0
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1] 
data
# Out:
# 2022-11-01    153548.0
# 2022-10-01    153285.0
# 2022-09-01    153001.0
# 2022-08-01    152732.0
# 2022-07-01    152440.0
#                 ...
# 1939-05-01     30299.0
# 1939-04-01     30094.0
# 1939-03-01     30280.0
# 1939-02-01     30100.0
# 1939-01-01     29923.0
# Length: 1007, dtype: float64

# %%
# take newest date to 1998/11
data = data.iloc[0:288]
data
# Out:
# 2022-11-01    153548.0
# 2022-10-01    153285.0
# 2022-09-01    153001.0
# 2022-08-01    152732.0
# 2022-07-01    152440.0
#                 ...
# 1999-04-01    128597.0
# 1999-03-01    128227.0
# 1999-02-01    128120.0
# 1999-01-01    127702.0
# 1998-12-01    127596.0
# Length: 288, dtype: float64

# %%
import pandas as pd
SP500 = pd.read_csv("SP_500_Monthly_price.csv", encoding="GB18030")
SP500
# Out:
#           Date  Adj Close
# 0    9/30/2022    3871.98
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
# [288 rows x 2 columns]

# %%
SP500['Total Employment'] = data.values
SP500
# Out:
#           Date  Adj Close  Total Employment
# 0    9/30/2022    3871.98          153548.0
# 1    8/31/2022    3585.62          153285.0
# 2    7/31/2022    3955.00          153001.0
# 3    6/30/2022    4130.29          152732.0
# 4    5/31/2022    3785.38          152440.0
# ..         ...        ...               ...
# 283   3/1/1999    1286.37          128597.0
# 284   2/1/1999    1238.33          128227.0
# 285   1/1/1999    1279.64          128120.0
# 286  12/1/1998    1229.23          127702.0
# 287  11/1/1998    1163.63          127596.0
#
# [288 rows x 3 columns]

# %%
import numpy as np
pearsons_coefficient = np.corrcoef(SP500['Adj Close'], SP500['Total Employment'])
pearsons_coefficient
# Out:
# array([[1.        , 0.85215092],
#        [0.85215092, 1.        ]])

# %%
SP500.to_csv('Total Employment.csv',index=False)

# %% [markdown]
# # Manufacturer's new orders for non-defense capital goods

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('ANDENO') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-01-01    87017.0
# 2022-02-01    83414.0
# 2022-03-01    83064.0
# 2022-04-01    83294.0
# 2022-05-01    84070.0
# 2022-06-01    84937.0
# 2022-07-01    87100.0
# 2022-08-01    86162.0
# 2022-09-01    89313.0
# 2022-10-01    90983.0
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1]
data
# Out:
# 2022-10-01    90983.0
# 2022-09-01    89313.0
# 2022-08-01    86162.0
# 2022-07-01    87100.0
# 2022-06-01    84937.0
#                ...
# 1992-06-01    39395.0
# 1992-05-01    40883.0
# 1992-04-01    39905.0
# 1992-03-01    39492.0
# 1992-02-01    35981.0
# Length: 369, dtype: float64

# %%
# take newest date to 1998/11
data = data.iloc[0:288]
data
# Out:
# 2022-10-01    90983.0
# 2022-09-01    89313.0
# 2022-08-01    86162.0
# 2022-07-01    87100.0
# 2022-06-01    84937.0
#                ...
# 1999-03-01    61480.0
# 1999-02-01    62053.0
# 1999-01-01    63726.0
# 1998-12-01    58598.0
# 1998-11-01    62463.0
# Length: 288, dtype: float64

# %%
SP500 = pd.read_csv("SP_500_Monthly_price.csv", encoding="GB18030")
SP500
# Out:
#           Date  Adj Close
# 0    9/30/2022    3871.98
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
# [288 rows x 2 columns]

# %%
SP500['Manufacturers new orders for non-defense capital goods'] = data.values
SP500
# Out:
#           Date  Adj Close  \
# 0    9/30/2022    3871.98
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
#      Manufacturers new orders for non-defense capital goods
# 0                                              90983.0
# 1                                              89313.0
# 2                                              86162.0
# 3                                              87100.0
# 4                                              84937.0
# ..                                                 ...
# 283                                            61480.0
# 284                                            62053.0
# 285                                            63726.0
# 286                                            58598.0
# ...

# %%
pearsons_coefficient = np.corrcoef(SP500['Adj Close'], SP500['Manufacturers new orders for non-defense capital goods'])
pearsons_coefficient
# Out:
# array([[1.        , 0.33579035],
#        [0.33579035, 1.        ]])

# %%
SP500.to_csv('Manufacturers new orders for non-defense capital goods.csv',index=False)

# %% [markdown]
# # Manufacturer's new orders for consumer goods and materials

# %%
data = fred.get_series('ACOGNO') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2021-12-01    210583.0
# 2022-01-01    213272.0
# 2022-02-01    216803.0
# 2022-03-01    225614.0
# 2022-04-01    228053.0
# 2022-05-01    235986.0
# 2022-06-01    240785.0
# 2022-07-01    235138.0
# 2022-08-01    235720.0
# 2022-09-01    237966.0
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1]
data
# Out:
# 2022-09-01    237966.0
# 2022-08-01    235720.0
# 2022-07-01    235138.0
# 2022-06-01    240785.0
# 2022-05-01    235986.0
#                 ...
# 1992-06-01     93632.0
# 1992-05-01     92615.0
# 1992-04-01     90535.0
# 1992-03-01     90386.0
# 1992-02-01     86445.0
# Length: 368, dtype: float64

# %%
# take newest date to 1998/11
data = data.iloc[0:287]
data
# Out:
# 2022-09-01    237966.0
# 2022-08-01    235720.0
# 2022-07-01    235138.0
# 2022-06-01    240785.0
# 2022-05-01    235986.0
#                 ...
# 1999-03-01    117056.0
# 1999-02-01    117580.0
# 1999-01-01    114899.0
# 1998-12-01    113627.0
# 1998-11-01    112727.0
# Length: 287, dtype: float64

# %%
SP500 = pd.read_csv("SP_500_Monthly_price.csv", encoding="GB18030")
SP500 = SP500[1:288]
SP500
# Out:
#           Date  Adj Close
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# 5    4/30/2021    4132.15
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
# [287 rows x 2 columns]

# %%
SP500['Manufacturers new orders for consumer goods and materials'] = data.values
SP500
# Out:
#           Date  Adj Close  \
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# 5    4/30/2021    4132.15
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
#      Manufacturers new orders for consumer goods and materials
# 1                                             237966.0
# 2                                             235720.0
# 3                                             235138.0
# 4                                             240785.0
# 5                                             235986.0
# ..                                                 ...
# 283                                           117056.0
# 284                                           117580.0
# 285                                           114899.0
# 286                                           113627.0
# ...

# %%
pearsons_coefficient = np.corrcoef(SP500['Adj Close'], SP500['Manufacturers new orders for consumer goods and materials'])
pearsons_coefficient
# Out:
# array([[1.        , 0.59692025],
#        [0.59692025, 1.        ]])

# %%
SP500.to_csv('Manufacturers new orders for consumer goods and materials.csv',index=False)

# %% [markdown]
# # Building permits for new private housing units

# %%
data = fred.get_series('PERMIT') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-01-01    1841.0
# 2022-02-01    1857.0
# 2022-03-01    1879.0
# 2022-04-01    1823.0
# 2022-05-01    1695.0
# 2022-06-01    1696.0
# 2022-07-01    1685.0
# 2022-08-01    1542.0
# 2022-09-01    1564.0
# 2022-10-01    1512.0
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1]
data
# Out:
# 2022-10-01    1512.0
# 2022-09-01    1564.0
# 2022-08-01    1542.0
# 2022-07-01    1685.0
# 2022-06-01    1696.0
#                ...
# 1960-05-01    1052.0
# 1960-04-01    1016.0
# 1960-03-01     955.0
# 1960-02-01    1088.0
# 1960-01-01    1092.0
# Length: 754, dtype: float64

# %%
# take newest date to 1998/11
data = data.iloc[0:288]
data
# Out:
# 2022-10-01    1512.0
# 2022-09-01    1564.0
# 2022-08-01    1542.0
# 2022-07-01    1685.0
# 2022-06-01    1696.0
#                ...
# 1999-03-01    1665.0
# 1999-02-01    1720.0
# 1999-01-01    1732.0
# 1998-12-01    1742.0
# 1998-11-01    1672.0
# Length: 288, dtype: float64

# %%
SP500 = pd.read_csv("SP_500_Monthly_price.csv", encoding="GB18030")
SP500
# Out:
#           Date  Adj Close
# 0    9/30/2022    3871.98
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
# [288 rows x 2 columns]

# %%
SP500['Building permits for new private housing units'] = data.values
SP500
# Out:
#           Date  Adj Close  Building permits for new private housing units
# 0    9/30/2022    3871.98                                          1512.0
# 1    8/31/2022    3585.62                                          1564.0
# 2    7/31/2022    3955.00                                          1542.0
# 3    6/30/2022    4130.29                                          1685.0
# 4    5/31/2022    3785.38                                          1696.0
# ..         ...        ...                                             ...
# 283   3/1/1999    1286.37                                          1665.0
# 284   2/1/1999    1238.33                                          1720.0
# 285   1/1/1999    1279.64                                          1732.0
# 286  12/1/1998    1229.23                                          1742.0
# 287  11/1/1998    1163.63                                          1672.0
#
# [288 rows x 3 columns]

# %%
pearsons_coefficient = np.corrcoef(SP500['Adj Close'], SP500['Building permits for new private housing units'])
pearsons_coefficient
# Out:
# array([[1.       , 0.1365189],
#        [0.1365189, 1.       ]])

# %%
SP500.to_csv('Building permits for new private housing units.csv',index=False)

# %% [markdown]
# # Consumer Expectation

# %%
data = fred.get_series('UMCSENT') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-01-01    67.2
# 2022-02-01    62.8
# 2022-03-01    59.4
# 2022-04-01    65.2
# 2022-05-01    58.4
# 2022-06-01    50.0
# 2022-07-01    51.5
# 2022-08-01    58.2
# 2022-09-01    58.6
# 2022-10-01    59.9
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1]
data
# Out:
# 2022-10-01    59.9
# 2022-09-01    58.6
# 2022-08-01    58.2
# 2022-07-01    51.5
# 2022-06-01    50.0
#               ...
# 1953-03-01     NaN
# 1953-02-01    90.7
# 1953-01-01     NaN
# 1952-12-01     NaN
# 1952-11-01    86.2
# Length: 840, dtype: float64

# %%
# take newest date to 1998/11
data = data.iloc[0:288]
data
# Out:
# 2022-10-01     59.9
# 2022-09-01     58.6
# 2022-08-01     58.2
# 2022-07-01     51.5
# 2022-06-01     50.0
#               ...
# 1999-03-01    105.7
# 1999-02-01    108.1
# 1999-01-01    103.9
# 1998-12-01    100.5
# 1998-11-01    102.7
# Length: 288, dtype: float64

# %%
SP500 = pd.read_csv("SP_500_Monthly_price.csv", encoding="GB18030")
SP500
# Out:
#           Date  Adj Close
# 0    9/30/2022    3871.98
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
# [288 rows x 2 columns]

# %%
SP500['Consumer Expectation'] = data.values
SP500
# Out:
#           Date  Adj Close  Consumer Expectation
# 0    9/30/2022    3871.98                  59.9
# 1    8/31/2022    3585.62                  58.6
# 2    7/31/2022    3955.00                  58.2
# 3    6/30/2022    4130.29                  51.5
# 4    5/31/2022    3785.38                  50.0
# ..         ...        ...                   ...
# 283   3/1/1999    1286.37                 105.7
# 284   2/1/1999    1238.33                 108.1
# 285   1/1/1999    1279.64                 103.9
# 286  12/1/1998    1229.23                 100.5
# 287  11/1/1998    1163.63                 102.7
#
# [288 rows x 3 columns]

# %%
pearsons_coefficient = np.corrcoef(SP500['Adj Close'], SP500['Consumer Expectation'])
pearsons_coefficient
# Out:
# array([[ 1.        , -0.07548559],
#        [-0.07548559,  1.        ]])

# %%
SP500.to_csv('Consumer Expectation.csv',index=False)

# %% [markdown]
# # Average Weekly Hours of Production and Nonsupervisory Employees, Manufacturing

# %%
data = fred.get_series('AWHMAN') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-02-01    41.6
# 2022-03-01    41.5
# 2022-04-01    41.2
# 2022-05-01    41.2
# 2022-06-01    41.0
# 2022-07-01    41.1
# 2022-08-01    41.0
# 2022-09-01    41.1
# 2022-10-01    41.0
# 2022-11-01    40.9
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1]
data
# Out:
# 2022-11-01    40.9
# 2022-10-01    41.0
# 2022-09-01    41.1
# 2022-08-01    41.0
# 2022-07-01    41.1
#               ...
# 1932-05-01     NaN
# 1932-04-01     NaN
# 1932-03-01     NaN
# 1932-02-01     NaN
# 1932-01-01     NaN
# Length: 1091, dtype: float64

# %%
# take newest date to 1998/11
data = data.iloc[0:288]
data
# Out:
# 2022-11-01    40.9
# 2022-10-01    41.0
# 2022-09-01    41.1
# 2022-08-01    41.0
# 2022-07-01    41.1
#               ...
# 1999-04-01    41.3
# 1999-03-01    41.3
# 1999-02-01    41.4
# 1999-01-01    41.3
# 1998-12-01    41.5
# Length: 288, dtype: float64

# %%
SP500 = pd.read_csv("SP_500_Monthly_price.csv", encoding="GB18030")
SP500
# Out:
#           Date  Adj Close
# 0    9/30/2022    3871.98
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
# [288 rows x 2 columns]

# %%
SP500['Average Weekly Hours of Production and Nonsupervisory Employees, Manufacturing'] = data.values
SP500
# Out:
#           Date  Adj Close  \
# 0    9/30/2022    3871.98
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
#      Average Weekly Hours of Production and Nonsupervisory Employees, Manufacturing
# 0                                                 40.9
# 1                                                 41.0
# 2                                                 41.1
# 3                                                 41.0
# 4                                                 41.1
# ..                                                 ...
# 283                                               41.3
# 284                                               41.3
# 285                                               41.4
# 286                                               41.3
# ...

# %%
pearsons_coefficient = np.corrcoef(SP500['Adj Close'], SP500['Average Weekly Hours of Production and Nonsupervisory Employees, Manufacturing'])
pearsons_coefficient
# Out:
# array([[1.        , 0.39800983],
#        [0.39800983, 1.        ]])

# %%
SP500.to_csv('Average Weekly Hours of Production and Nonsupervisory Employees, Manufacturing.csv',index=False)

# %% [markdown]
# # Real Disposable Personal Income

# %%
data = fred.get_series('DSPIC96') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-01-01    15137.7
# 2022-02-01    15125.6
# 2022-03-01    15064.1
# 2022-04-01    15055.2
# 2022-05-01    15036.4
# 2022-06-01    14973.1
# 2022-07-01    15050.5
# 2022-08-01    15060.5
# 2022-09-01    15056.9
# 2022-10-01    15113.3
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1]
data
# Out:
# 2022-10-01    15113.3
# 2022-09-01    15056.9
# 2022-08-01    15060.5
# 2022-07-01    15050.5
# 2022-06-01    14973.1
#                ...
# 1959-05-01     2237.1
# 1959-04-01     2225.0
# 1959-03-01     2210.7
# 1959-02-01     2198.1
# 1959-01-01     2191.5
# Length: 766, dtype: float64

# %%
# take newest date to 1998/11
data = data.iloc[0:287]
data
# Out:
# 2022-10-01    15113.3
# 2022-09-01    15056.9
# 2022-08-01    15060.5
# 2022-07-01    15050.5
# 2022-06-01    14973.1
#                ...
# 1999-04-01     8969.0
# 1999-03-01     8996.9
# 1999-02-01     8987.9
# 1999-01-01     8956.4
# 1998-12-01     8907.1
# Length: 287, dtype: float64

# %%
SP500 = pd.read_csv("SP_500_Monthly_price.csv", encoding="GB18030")
SP500 = SP500.iloc[1:288]
SP500
# Out:
#           Date  Adj Close
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# 5    4/30/2021    4132.15
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
# [287 rows x 2 columns]

# %%
SP500['Real Disposable Personal Income'] = data.values
SP500
# Out:
#           Date  Adj Close  Real Disposable Personal Income
# 1    8/31/2022    3585.62                          15113.3
# 2    7/31/2022    3955.00                          15056.9
# 3    6/30/2022    4130.29                          15060.5
# 4    5/31/2022    3785.38                          15050.5
# 5    4/30/2021    4132.15                          14973.1
# ..         ...        ...                              ...
# 283   3/1/1999    1286.37                           8969.0
# 284   2/1/1999    1238.33                           8996.9
# 285   1/1/1999    1279.64                           8987.9
# 286  12/1/1998    1229.23                           8956.4
# 287  11/1/1998    1163.63                           8907.1
#
# [287 rows x 3 columns]

# %%
pearsons_coefficient = np.corrcoef(SP500['Adj Close'], SP500['Real Disposable Personal Income'])
pearsons_coefficient
# Out:
# array([[1.       , 0.8520132],
#        [0.8520132, 1.       ]])

# %%
SP500.to_csv('Real Disposable Personal Income.csv',index=False)

# %% [markdown]
# # Industrial Production: Total Index

# %%
data = fred.get_series('INDPRO') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-01-01    102.1460
# 2022-02-01    102.8987
# 2022-03-01    103.5717
# 2022-04-01    104.2709
# 2022-05-01    104.1646
# 2022-06-01    104.0772
# 2022-07-01    104.7577
# 2022-08-01    104.6544
# 2022-09-01    104.8050
# 2022-10-01    104.6894
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1]
data
# Out:
# 2022-10-01    104.6894
# 2022-09-01    104.8050
# 2022-08-01    104.6544
# 2022-07-01    104.7577
# 2022-06-01    104.0772
#                 ...
# 1919-05-01      4.6348
# 1919-04-01      4.6078
# 1919-03-01      4.5270
# 1919-02-01      4.6617
# 1919-01-01      4.8773
# Length: 1246, dtype: float64

# %%
# take newest date to 1998/11
data = data.iloc[0:288]
data
# Out:
# 2022-10-01    104.6894
# 2022-09-01    104.8050
# 2022-08-01    104.6544
# 2022-07-01    104.7577
# 2022-06-01    104.0772
#                 ...
# 1999-03-01     88.1101
# 1999-02-01     87.9260
# 1999-01-01     87.4252
# 1998-12-01     87.0633
# 1998-11-01     86.6929
# Length: 288, dtype: float64

# %%
SP500 = pd.read_csv("SP_500_Monthly_price.csv", encoding="GB18030")
SP500
# Out:
#           Date  Adj Close
# 0    9/30/2022    3871.98
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
# [288 rows x 2 columns]

# %%
SP500['Industrial Production: Total Index'] = data.values
SP500
# Out:
#           Date  Adj Close  Industrial Production: Total Index
# 0    9/30/2022    3871.98                            104.6894
# 1    8/31/2022    3585.62                            104.8050
# 2    7/31/2022    3955.00                            104.6544
# 3    6/30/2022    4130.29                            104.7577
# 4    5/31/2022    3785.38                            104.0772
# ..         ...        ...                                 ...
# 283   3/1/1999    1286.37                             88.1101
# 284   2/1/1999    1238.33                             87.9260
# 285   1/1/1999    1279.64                             87.4252
# 286  12/1/1998    1229.23                             87.0633
# 287  11/1/1998    1163.63                             86.6929
#
# [288 rows x 3 columns]

# %%
pearsons_coefficient = np.corrcoef(SP500['Adj Close'], SP500['Industrial Production: Total Index'])
pearsons_coefficient
# Out:
# array([[1.        , 0.60767836],
#        [0.60767836, 1.        ]])

# %%
SP500.to_csv('Industrial Production: Total Index.csv',index=False)

# %% [markdown]
# # Call Money/Interbank Rate for the United States

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('IRSTCI01USM156N') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-01-01    0.08
# 2022-02-01    0.08
# 2022-03-01    0.20
# 2022-04-01    0.33
# 2022-05-01    0.77
# 2022-06-01    1.21
# 2022-07-01    1.68
# 2022-08-01    2.33
# 2022-09-01    2.56
# 2022-10-01    3.08
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1]
data
# Out:
# 2022-10-01    3.08
# 2022-09-01    2.56
# 2022-08-01    2.33
# 2022-07-01    1.68
# 2022-06-01    1.21
#               ...
# 1955-05-01     NaN
# 1955-04-01     NaN
# 1955-03-01     NaN
# 1955-02-01     NaN
# 1955-01-01     NaN
# Length: 814, dtype: float64

# %%
# take newest date to 1998/11
data = data.iloc[0:288]
data
# Out:
# 2022-10-01    3.08
# 2022-09-01    2.56
# 2022-08-01    2.33
# 2022-07-01    1.68
# 2022-06-01    1.21
#               ...
# 1999-03-01    4.81
# 1999-02-01    4.76
# 1999-01-01    4.63
# 1998-12-01    4.68
# 1998-11-01    4.83
# Length: 288, dtype: float64

# %%
SP500 = pd.read_csv("SP_500_Monthly_price.csv", encoding="GB18030")
SP500
# Out:
#           Date  Adj Close
# 0    9/30/2022    3871.98
# 1    8/31/2022    3585.62
# 2    7/31/2022    3955.00
# 3    6/30/2022    4130.29
# 4    5/31/2022    3785.38
# ..         ...        ...
# 283   3/1/1999    1286.37
# 284   2/1/1999    1238.33
# 285   1/1/1999    1279.64
# 286  12/1/1998    1229.23
# 287  11/1/1998    1163.63
#
# [288 rows x 2 columns]

# %%
SP500['Call Money/Interbank Rate for the United States'] = data.values
SP500
# Out:
#           Date  Adj Close  Call Money/Interbank Rate for the United States
# 0    9/30/2022    3871.98                                             3.08
# 1    8/31/2022    3585.62                                             2.56
# 2    7/31/2022    3955.00                                             2.33
# 3    6/30/2022    4130.29                                             1.68
# 4    5/31/2022    3785.38                                             1.21
# ..         ...        ...                                              ...
# 283   3/1/1999    1286.37                                             4.81
# 284   2/1/1999    1238.33                                             4.76
# 285   1/1/1999    1279.64                                             4.63
# 286  12/1/1998    1229.23                                             4.68
# 287  11/1/1998    1163.63                                             4.83
#
# [288 rows x 3 columns]

# %%
pearsons_coefficient = np.corrcoef(SP500['Adj Close'], SP500['Call Money/Interbank Rate for the United States'])
pearsons_coefficient
# Out:
# array([[ 1.        , -0.26310506],
#        [-0.26310506,  1.        ]])

# %%
SP500.to_csv('Call Money|Interbank Rate for the United States.csv',index=False)

# %% [markdown]
# # M2 Velocity

# %%
from fredapi import Fred
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('M2V') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2020-04-01    1.112
# 2020-07-01    1.161
# 2020-10-01    1.146
# 2021-01-01    1.138
# 2021-04-01    1.134
# 2021-07-01    1.132
# 2021-10-01    1.142
# 2022-01-01    1.140
# 2022-04-01    1.167
# 2022-07-01    1.191
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1]
data
# Out:
# 2022-07-01    1.191
# 2022-04-01    1.167
# 2022-01-01    1.140
# 2021-10-01    1.142
# 2021-07-01    1.132
#               ...
# 1960-01-01    1.817
# 1959-10-01    1.779
# 1959-07-01    1.773
# 1959-04-01    1.789
# 1959-01-01    1.773
# Length: 255, dtype: float64

# %%
import pandas as pd
SP500 = pd.read_csv("S&P 500 Data.csv")
SP500
# Out:
#             Date    Price
# 0     2023-01-06  3895.08
# 1     2023-01-05  3808.10
# 2     2023-01-04  3852.97
# 3     2023-01-03  3824.14
# 4     2022-12-30  3839.50
# ...          ...      ...
# 6080  1998-11-06  1141.00
# 6081  1998-11-05  1133.80
# 6082  1998-11-04  1118.70
# 6083  1998-11-03  1110.80
# 6084  1998-11-02  1111.60
#
# [6085 rows x 2 columns]

# %%
data = pd.DataFrame(data)
data['Date'] = data.index
data = data.reset_index()
data = data.drop(['index'],axis=1)

# %%
data
# Out:
#          0       Date
# 0    1.191 2022-07-01
# 1    1.167 2022-04-01
# 2    1.140 2022-01-01
# 3    1.142 2021-10-01
# 4    1.132 2021-07-01
# ..     ...        ...
# 250  1.817 1960-01-01
# 251  1.779 1959-10-01
# 252  1.773 1959-07-01
# 253  1.789 1959-04-01
# 254  1.773 1959-01-01
#
# [255 rows x 2 columns]

# %%
data['Date'] = data['Date'].astype('datetime64[ns]')
SP500['Date'] = SP500['Date'].astype('datetime64[ns]')

# %%
merged_data = pd.merge(data, SP500, how='left', on = 'Date')

# %%
merged_data.rename(columns = {0:'Velocity of M2 Money Stock'}, inplace = True)

# %% [markdown]
# merged_data['Velocity of M2 Money Stock'] = pd.to_numeric(merged_data['Velocity of M2 Money Stock'])
# merged_data['Price'] = pd.to_numeric(merged_data['Price'])

# %%
merged_data
# Out:
#      Velocity of M2 Money Stock       Date    Price
# 0                         1.191 2022-07-01  3825.33
# 1                         1.167 2022-04-01  4545.86
# 2                         1.140 2022-01-01      NaN
# 3                         1.142 2021-10-01  4357.05
# 4                         1.132 2021-07-01  4319.94
# ..                          ...        ...      ...
# 250                       1.817 1960-01-01      NaN
# 251                       1.779 1959-10-01      NaN
# 252                       1.773 1959-07-01      NaN
# 253                       1.789 1959-04-01      NaN
# 254                       1.773 1959-01-01      NaN
#
# [255 rows x 3 columns]

# %%
import numpy as np
pearsons_coefficient = np.corrcoef(merged_data['Price'], merged_data['Velocity of M2 Money Stock'])
pearsons_coefficient
# Out:
# array([[ 1.        , -0.85614219],
#        [-0.85614219,  1.        ]])

# %%
merged_data.to_csv('Velocity of M2 Money Stock.csv',index=False)

# %% [markdown]
# # Federal Government: Current Expenditures

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('FGEXPND') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2020-04-01    8896.416
# 2020-07-01    7116.015
# 2020-10-01    5877.529
# 2021-01-01    8178.958
# 2021-04-01    7649.622
# 2021-07-01    6709.184
# 2021-10-01    6079.752
# 2022-01-01    5891.599
# 2022-04-01    5935.195
# 2022-07-01    6063.491
# dtype: float64

# %%
# inverse order 
data = data.iloc[::-1]
data
# Out:
# 2022-07-01    6063.491
# 2022-04-01    5935.195
# 2022-01-01    5891.599
# 2021-10-01    6079.752
# 2021-07-01    6709.184
#                 ...
# 1947-01-01      40.902
# 1946-10-01         NaN
# 1946-07-01         NaN
# 1946-04-01         NaN
# 1946-01-01         NaN
# Length: 307, dtype: float64

# %%
data = pd.DataFrame(data)
data['Date'] = data.index
data = data.reset_index()
data = data.drop(['index'],axis=1)

# %%
data['Date'] = data['Date'].astype('datetime64[ns]')
SP500['Date'] = SP500['Date'].astype('datetime64[ns]')
merged_data = pd.merge(data, SP500, how='inner', on = 'Date')

# %%
merged_data.rename(columns = {0:'Federal Government: Current Expenditures'}, inplace = True)
merged_data
# Out:
#     Federal Government: Current Expenditures       Date    Price
# 0                                   6063.491 2022-07-01  3825.33
# 1                                   5935.195 2022-04-01  4545.86
# 2                                   6079.752 2021-10-01  4357.05
# 3                                   6709.184 2021-07-01  4319.94
# 4                                   7649.622 2021-04-01  4019.87
# 5                                   5877.529 2020-10-01  3380.80
# 6                                   7116.015 2020-07-01  3115.86
# 7                                   8896.416 2020-04-01  2470.50
# 8                                   4801.462 2019-10-01  2940.25
# 9                                   4787.303 2019-07-01  2964.33
# 10                                  4751.406 2019-04-01  2867.19
# 11                                  4599.679 2018-10-01  2924.59
# 12                                  4153.525 2016-07-01  2102.95
# ...

# %%
pearsons_coefficient = np.corrcoef(merged_data['Price'], merged_data['Federal Government: Current Expenditures'])
pearsons_coefficient
# Out:
# array([[1.        , 0.81881021],
#        [0.81881021, 1.        ]])

# %%
merged_data.to_csv('Federal Government: Current Expenditures.csv',index=False)

# %% [markdown]
# # Imports of Goods and Services

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('IMPGS') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2020-04-01    2343.723
# 2020-07-01    2798.970
# 2020-10-01    3026.384
# 2021-01-01    3177.739
# 2021-04-01    3337.485
# 2021-07-01    3442.476
# 2021-10-01    3647.745
# 2022-01-01    3927.908
# 2022-04-01    4074.409
# 2022-07-01    3955.795
# dtype: float64

# %%
data = pd.DataFrame(data)
data['Date'] = data.index
data = data.reset_index()
data = data.drop(['index'],axis=1)
data
# Out:
#             0       Date
# 0         NaN 1946-01-01
# 1         NaN 1946-04-01
# 2         NaN 1946-07-01
# 3         NaN 1946-10-01
# 4       7.519 1947-01-01
# ..        ...        ...
# 302  3442.476 2021-07-01
# 303  3647.745 2021-10-01
# 304  3927.908 2022-01-01
# 305  4074.409 2022-04-01
# 306  3955.795 2022-07-01
#
# [307 rows x 2 columns]

# %%
data['Date'] = data['Date'].astype('datetime64[ns]')
SP500['Date'] = SP500['Date'].astype('datetime64[ns]')
merged_data = pd.merge(data, SP500, how='inner', on = 'Date')

# %%
merged_data.rename(columns = {0:'Imports of Goods and Services'}, inplace = True)
merged_data
# Out:
#     Imports of Goods and Services       Date    Price
# 0                        1222.126 1999-04-01  1293.70
# 1                        1281.712 1999-07-01  1381.00
# 2                        1332.679 1999-10-01  1282.80
# 3                        1323.208 2001-10-01  1038.50
# 4                        1432.413 2002-04-01  1146.50
# 5                        1463.107 2002-07-01   968.60
# 6                        1499.335 2002-10-01   847.90
# 7                        1527.336 2003-04-01   858.50
# 8                        1556.304 2003-07-01   982.30
# 9                        1615.376 2003-10-01  1018.20
# 10                       1787.734 2004-04-01  1132.20
# 11                       1832.856 2004-07-01  1128.90
# 12                       1921.780 2004-10-01  1131.50
# 13                       2002.063 2005-04-01  1172.90
# 14                       2053.275 2005-07-01  1194.40
# 15                       2480.413 2007-10-01  1547.04
# ...

# %%
pearsons_coefficient = np.corrcoef(merged_data['Price'], merged_data['Imports of Goods and Services'])
pearsons_coefficient
# Out:
# array([[1.        , 0.81327083],
#        [0.81327083, 1.        ]])

# %%
merged_data.to_csv('Imports of Goods and Services.csv',index=False)

# %% [markdown]
# # Export Price Index (End Use): All Commodities

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('IQ') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-02-01    153.0
# 2022-03-01    159.0
# 2022-04-01    160.6
# 2022-05-01    164.9
# 2022-06-01    166.7
# 2022-07-01    160.5
# 2022-08-01    158.3
# 2022-09-01    156.8
# 2022-10-01    156.2
# 2022-11-01    155.8
# dtype: float64

# %%
data = pd.DataFrame(data)
data['Date'] = data.index
data = data.reset_index()
data = data.drop(['index'],axis=1)
data
# Out:
#          0       Date
# 0     85.7 1983-09-01
# 1      NaN 1983-10-01
# 2      NaN 1983-11-01
# 3     85.4 1983-12-01
# 4      NaN 1984-01-01
# ..     ...        ...
# 466  160.5 2022-07-01
# 467  158.3 2022-08-01
# 468  156.8 2022-09-01
# 469  156.2 2022-10-01
# 470  155.8 2022-11-01
#
# [471 rows x 2 columns]

# %%
#data['Date'] = data['Date'].astype('datetime64[ns]')
#SP500['Date'] = SP500['Date'].astype('datetime64[ns]')
merged_data = pd.merge(data, SP500, how='inner', on = 'Date')
merged_data.rename(columns = {0:'Export Price Index (End Use): All Commodities'}, inplace = True)
merged_data
# Out:
#      Export Price Index (End Use): All Commodities       Date    Price
# 0                                             98.5 1998-12-01  1175.30
# 1                                             98.3 1999-02-01  1273.00
# 2                                             97.9 1999-03-01  1236.20
# 3                                             98.1 1999-04-01  1293.70
# 4                                             98.2 1999-06-01  1294.30
# ..                                             ...        ...      ...
# 182                                          166.7 2022-06-01  4101.23
# 183                                          160.5 2022-07-01  3825.33
# 184                                          158.3 2022-08-01  4118.63
# 185                                          156.8 2022-09-01  3966.85
# 186                                          155.8 2022-11-01  3856.10
#
# [187 rows x 3 columns]

# %%
pearsons_coefficient = np.corrcoef(merged_data['Price'], merged_data['Export Price Index (End Use): All Commodities'])
pearsons_coefficient
# Out:
# array([[1.        , 0.68698054],
#        [0.68698054, 1.        ]])

# %%
merged_data.to_csv('Export Price Index (End Use): All Commodities.csv',index=False)

# %% [markdown]
# # Economic Policy Uncertainty Index for United States

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('USEPUINDXD') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-12-27     59.72
# 2022-12-28     75.98
# 2022-12-29    124.58
# 2022-12-30    200.63
# 2022-12-31    163.79
# 2023-01-01    450.76
# 2023-01-02    181.97
# 2023-01-03    120.90
# 2023-01-04    119.82
# 2023-01-05    274.56
# dtype: float64

# %%
data = pd.DataFrame(data)
data['Date'] = data.index
data = data.reset_index()
data = data.drop(['index'],axis=1)
data
# Out:
#             0       Date
# 0      103.83 1985-01-01
# 1      296.43 1985-01-02
# 2       56.06 1985-01-03
# 3      118.45 1985-01-04
# 4       88.56 1985-01-05
# ...       ...        ...
# 13879  450.76 2023-01-01
# 13880  181.97 2023-01-02
# 13881  120.90 2023-01-03
# 13882  119.82 2023-01-04
# 13883  274.56 2023-01-05
#
# [13884 rows x 2 columns]

# %%
merged_data = pd.merge(data, SP500, how='inner', on = 'Date')
merged_data.rename(columns = {0:'Economic Policy Uncertainty Index for United States'}, inplace = True)
merged_data
# Out:
#       Economic Policy Uncertainty Index for United States       Date    Price
# 0                                                 79.09   1998-11-02  1111.60
# 1                                                 54.32   1998-11-03  1110.80
# 2                                                 71.17   1998-11-04  1118.70
# 3                                                139.86   1998-11-05  1133.80
# 4                                                 70.38   1998-11-06  1141.00
# ...                                                 ...          ...      ...
# 6079                                             124.58   2022-12-29  3849.28
# 6080                                             200.63   2022-12-30  3839.50
# 6081                                             120.90   2023-01-03  3824.14
# 6082                                             119.82   2023-01-04  3852.97
# 6083                                             274.56   2023-01-05  3808.10
#
# [6084 rows x 3 columns]

# %%
pearsons_coefficient = np.corrcoef(merged_data['Price'], merged_data['Economic Policy Uncertainty Index for United States'])
pearsons_coefficient
# Out:
# array([[1.        , 0.14526146],
#        [0.14526146, 1.        ]])

# %%
merged_data.to_csv('Economic Policy Uncertainty Index for United States.csv',index=False)

# %% [markdown]
# # Security Brokers and Dealers; Margin Accounts at Brokers and Dealers; Asset, Level

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('BOGZ1FL663067003Q') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2020-04-01    319488.0
# 2020-07-01    385048.0
# 2020-10-01    482375.0
# 2021-01-01    573708.0
# 2021-04-01    595233.0
# 2021-07-01    571464.0
# 2021-10-01    574733.0
# 2022-01-01    582855.0
# 2022-04-01    542715.0
# 2022-07-01    539980.0
# dtype: float64

# %%
data = pd.DataFrame(data)
data['Date'] = data.index
data = data.reset_index()
data = data.drop(['index'],axis=1)
data
# Out:
#             0       Date
# 0      1252.0 1945-10-01
# 1         NaN 1946-01-01
# 2         NaN 1946-04-01
# 3         NaN 1946-07-01
# 4       594.0 1946-10-01
# ..        ...        ...
# 303  571464.0 2021-07-01
# 304  574733.0 2021-10-01
# 305  582855.0 2022-01-01
# 306  542715.0 2022-04-01
# 307  539980.0 2022-07-01
#
# [308 rows x 2 columns]

# %%
merged_data = pd.merge(data, SP500, how='inner', on = 'Date')
merged_data.rename(columns = {0:'Security Brokers and Dealers; Margin Accounts at Brokers and Dealers; Asset, Level'}, inplace = True)
merged_data
# Out:
#     Security Brokers and Dealers; Margin Accounts at Brokers and Dealers; Asset, Level  \
# 0                                            183825.0
# 1                                            185837.0
# 2                                            227926.0
# 3                                            196359.0
# 4                                            170555.0
# 5                                            149624.0
# 6                                            148201.0
# 7                                            248456.0
# 8                                            227610.0
# 9                                            182500.0
# 10                                           216509.0
# 11                                           209852.0
# 12                                           264019.0
# 13                                           263518.0
# 14                                           258013.0
# 15                                           325534.0
# ...

# %%
pearsons_coefficient = np.corrcoef(merged_data['Price'], merged_data['Security Brokers and Dealers; Margin Accounts at Brokers and Dealers; Asset, Level'])
pearsons_coefficient
# Out:
# array([[1.        , 0.87857136],
#        [0.87857136, 1.        ]])

# %%
merged_data.to_csv('Security Brokers and Dealers; Margin Accounts at Brokers and Dealers; Asset, Level.csv',index=False)

# %% [markdown]
# # 15-Year Fixed Rate Mortgage Average in the United States

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('MORTGAGE15US') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-11-03    6.29
# 2022-11-10    6.38
# 2022-11-17    5.98
# 2022-11-23    5.90
# 2022-12-01    5.76
# 2022-12-08    5.67
# 2022-12-15    5.54
# 2022-12-22    5.69
# 2022-12-29    5.68
# 2023-01-05    5.73
# dtype: float64

# %%
data = pd.DataFrame(data)
data['Date'] = data.index
data = data.reset_index()
data = data.drop(['index'],axis=1)
data
# Out:
#          0       Date
# 0     8.77 1991-08-30
# 1     8.79 1991-09-06
# 2     8.68 1991-09-13
# 3     8.62 1991-09-20
# 4     8.59 1991-09-27
# ...    ...        ...
# 1632  5.67 2022-12-08
# 1633  5.54 2022-12-15
# 1634  5.69 2022-12-22
# 1635  5.68 2022-12-29
# 1636  5.73 2023-01-05
#
# [1637 rows x 2 columns]

# %%
merged_data = pd.merge(data, SP500, how='inner', on = 'Date')
merged_data.rename(columns = {0:'15-Year Fixed Rate Mortgage Average in the United States'}, inplace = True)
merged_data
# Out:
#       15-Year Fixed Rate Mortgage Average in the United States       Date  \
# 0                                                  6.50        1998-11-06
# 1                                                  6.57        1998-11-13
# 2                                                  6.51        1998-11-20
# 3                                                  6.44        1998-11-27
# 4                                                  6.37        1998-12-04
# ...                                                 ...               ...
# 1248                                               5.67        2022-12-08
# 1249                                               5.54        2022-12-15
# 1250                                               5.69        2022-12-22
# 1251                                               5.68        2022-12-29
# 1252                                               5.73        2023-01-05
#
#         Price
# 0     1141.00
# 1     1125.70
# 2     1163.50
# 3     1192.30
# ...

# %%
pearsons_coefficient = np.corrcoef(merged_data['Price'], merged_data['15-Year Fixed Rate Mortgage Average in the United States'])
pearsons_coefficient
# Out:
# array([[ 1.        , -0.53060456],
#        [-0.53060456,  1.        ]])

# %%
merged_data.to_csv('15-Year Fixed Rate Mortgage Average in the United States.csv',index=False)

# %% [markdown]
# # Loan Performance: Total Loans and Leases: Noncurrent Rate

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('QBPLNTLNNCUR') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2020-04-01    1.075813
# 2020-07-01    1.165618
# 2020-10-01    1.185629
# 2021-01-01    1.135408
# 2021-04-01    1.010160
# 2021-07-01    0.940728
# 2021-10-01    0.886578
# 2022-01-01    0.838215
# 2022-04-01    0.747536
# 2022-07-01    0.719972
# dtype: float64

# %%
data = pd.DataFrame(data)
data['Date'] = data.index
data = data.reset_index()
data = data.drop(['index'],axis=1)
data
# Out:
#             0       Date
# 0    2.134269 1984-01-01
# 1    2.099341 1984-04-01
# 2    2.004352 1984-07-01
# 3    1.941187 1984-10-01
# 4    2.020531 1985-01-01
# ..        ...        ...
# 150  0.940728 2021-07-01
# 151  0.886578 2021-10-01
# 152  0.838215 2022-01-01
# 153  0.747536 2022-04-01
# 154  0.719972 2022-07-01
#
# [155 rows x 2 columns]

# %%
merged_data = pd.merge(data, SP500, how='inner', on = 'Date')
merged_data.rename(columns = {0:'Loan Performance: Total Loans and Leases: Noncurrent Rate'}, inplace = True)
merged_data
# Out:
#     Loan Performance: Total Loans and Leases: Noncurrent Rate       Date  \
# 0                                            0.908715         1999-04-01
# 1                                            0.937269         1999-07-01
# 2                                            0.906579         1999-10-01
# 3                                            1.304971         2001-10-01
# 4                                            1.366103         2002-04-01
# 5                                            1.391236         2002-07-01
# 6                                            1.363185         2002-10-01
# 7                                            1.235194         2003-04-01
# 8                                            1.168631         2003-07-01
# 9                                            1.122008         2003-10-01
# 10                                           0.890565         2004-04-01
# 11                                           0.846554         2004-07-01
# ...

# %%
pearsons_coefficient = np.corrcoef(merged_data['Price'], merged_data['Loan Performance: Total Loans and Leases: Noncurrent Rate'])
pearsons_coefficient
# Out:
# array([[ 1.        , -0.41575802],
#        [-0.41575802,  1.        ]])

# %%
merged_data.to_csv('Loan Performance: Total Loans and Leases: Noncurrent Rate.csv',index=False)

# %% [markdown]
# # Equity Market Volatility Tracker: Overall

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('EMVOVERALLEMV') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2022-03-01    23.04955
# 2022-04-01    20.31038
# 2022-05-01    27.86238
# 2022-06-01    17.10111
# 2022-07-01    24.53555
# 2022-08-01    14.14119
# 2022-09-01    16.86149
# 2022-10-01    20.86594
# 2022-11-01    17.70831
# 2022-12-01    20.68268
# dtype: float64

# %%
data = pd.DataFrame(data)
data['Date'] = data.index
data = data.reset_index()
data = data.drop(['index'],axis=1)
data
# Out:
#             0       Date
# 0    11.30402 1985-01-01
# 1     9.46174 1985-02-01
# 2    10.99764 1985-03-01
# 3     9.26745 1985-04-01
# 4     9.83628 1985-05-01
# ..        ...        ...
# 451  14.14119 2022-08-01
# 452  16.86149 2022-09-01
# 453  20.86594 2022-10-01
# 454  17.70831 2022-11-01
# 455  20.68268 2022-12-01
#
# [456 rows x 2 columns]

# %%
merged_data = pd.merge(data, SP500, how='inner', on = 'Date')
merged_data.rename(columns = {0:'Equity Market Volatility Tracker: Overall'}, inplace = True)
merged_data
# Out:
#      Equity Market Volatility Tracker: Overall       Date    Price
# 0                                     25.64142 1998-12-01  1175.30
# 1                                     21.43883 1999-02-01  1273.00
# 2                                     22.87707 1999-03-01  1236.20
# 3                                     21.43229 1999-04-01  1293.70
# 4                                     20.60151 1999-06-01  1294.30
# ..                                         ...        ...      ...
# 183                                   24.53555 2022-07-01  3825.33
# 184                                   14.14119 2022-08-01  4118.63
# 185                                   16.86149 2022-09-01  3966.85
# 186                                   17.70831 2022-11-01  3856.10
# 187                                   20.68268 2022-12-01  4076.57
#
# [188 rows x 3 columns]

# %%
pearsons_coefficient = np.corrcoef(merged_data['Price'], merged_data['Equity Market Volatility Tracker: Overall'])
pearsons_coefficient
# Out:
# array([[ 1.        , -0.04455957],
#        [-0.04455957,  1.        ]])

# %% [markdown]
# # Federal government current tax receipts

# %%
fred = Fred(api_key= 'f6111cac3afbe3680d59f72643824ac2') #Enter your key
data = fred.get_series('W006RC1Q027SBEA') #Enter table name corresponding to FRED site
data.tail(10)
# Out:
# 2020-04-01    1946.753
# 2020-07-01    2116.308
# 2020-10-01    2249.012
# 2021-01-01    2401.698
# 2021-04-01    2560.596
# 2021-07-01    2644.947
# 2021-10-01    2759.325
# 2022-01-01    3113.925
# 2022-04-01    3196.579
# 2022-07-01    3212.672
# dtype: float64

# %%
data = pd.DataFrame(data)
data['Date'] = data.index
data = data.reset_index()
data = data.drop(['index'],axis=1)
data
# Out:
#             0       Date
# 0      36.860 1947-01-01
# 1      36.316 1947-04-01
# 2      36.264 1947-07-01
# 3      38.744 1947-10-01
# 4      38.952 1948-01-01
# ..        ...        ...
# 298  2644.947 2021-07-01
# 299  2759.325 2021-10-01
# 300  3113.925 2022-01-01
# 301  3196.579 2022-04-01
# 302  3212.672 2022-07-01
#
# [303 rows x 2 columns]

# %%
merged_data = pd.merge(data, SP500, how='inner', on = 'Date')
merged_data.rename(columns = {0:'Federal government current tax receipts'}, inplace = True)
merged_data
# Out:
#     Federal government current tax receipts       Date    Price
# 0                                  1158.005 1999-04-01  1293.70
# 1                                  1182.148 1999-07-01  1381.00
# 2                                  1215.337 1999-10-01  1282.80
# 3                                  1210.806 2001-10-01  1038.50
# 4                                  1051.808 2002-04-01  1146.50
# 5                                  1047.885 2002-07-01   968.60
# 6                                  1057.477 2002-10-01   847.90
# 7                                  1074.610 2003-04-01   858.50
# 8                                   994.708 2003-07-01   982.30
# 9                                  1083.214 2003-10-01  1018.20
# 10                                 1122.200 2004-04-01  1132.20
# 11                                 1165.545 2004-07-01  1128.90
# 12                                 1188.485 2004-10-01  1131.50
# 13                                 1343.299 2005-04-01  1172.90
# ...

# %%
pearsons_coefficient = np.corrcoef(merged_data['Price'], merged_data['Federal government current tax receipts'])
pearsons_coefficient
# Out:
# array([[1.        , 0.94470277],
#        [0.94470277, 1.        ]])
